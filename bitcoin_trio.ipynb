# %% [markdown]
# # Data Management Project: Bitcoin sentiment analysis

# %% [markdown]
# ### Data sources:
# - Bitcoin Volume: API endpoint -> https://api.binance.com/api/v3/klines
# - NyTimes news: API endpoint -> https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=yourkey
#
# (Limit NYtimes: Yes, there are two rate limits per API: 500 requests per day and 5 requests per minute. You should sleep 12 seconds between calls to avoid hitting the per minute rate limit. If you need a higher rate limit, please contact us at code@nytimes.com.)

# %% [markdown]
# Important:
# - create in your environment a .env file
# - write: NY_KEY = "your_key"
# - use the command load_dotenv()
# - key = os.getenv("NY_KEY")

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.1
#
# [notice] A new release of pip available: 22.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install kafka-python pymongo
# Out:
# Requirement already satisfied: kafka-python in c:\users\tomma\appdata\local\programs\python\python311\lib\site-packages (2.3.0)
# Collecting pymongo
#   Downloading pymongo-4.15.5-cp311-cp311-win_amd64.whl (859 kB)
#      -------------------------------------- 859.2/859.2 kB 4.5 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#      -------------------------------------- 331.1/331.1 kB 6.8 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.5
#
# [notice] A new release of pip available: 22.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\tomma\appdata\roaming\python\python311\site-packages (from tqdm) (0.4.6)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1
#
# [notice] A new release of pip available: 22.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import json
from datetime import datetime, date, timedelta
import os
from dotenv import load_dotenv
import pandas as pd
import matplotlib.pyplot as plt
import time
from dateutil.relativedelta import relativedelta
from tqdm import tqdm

from kafka import KafkaProducer
from kafka import KafkaConsumer

from pymongo import MongoClient

load_dotenv()
# Out:
# True

# %% [markdown]
# ### BitCoin:

# %%
url = "https://api.binance.com/api/v3/klines"
params = {
    "symbol": "BTCUSDT",
    "interval": "1d",
    "limit": 10000
}

response = requests.get(url, params=params)
data = response.json()

# Converte le candele in un formato leggibile
candles = []
for c in data:
    open_time = datetime.fromtimestamp(c[0]/1000)   # converte ms → datetime
    open_price = float(c[1])
    high = float(c[2])
    low = float(c[3])
    close_price = float(c[4])

    candles.append({
        "date": open_time.strftime("%Y-%m-%d"),
        "open": open_price,
        "high": high,
        "low": low,
        "close": close_price
    })

for c in candles:
    print(c)
# Out:
# {'date': '2023-03-15', 'open': 24670.41, 'high': 25196.97, 'low': 23896.95, 'close': 24285.66}
# {'date': '2023-03-16', 'open': 24285.66, 'high': 25167.4, 'low': 24123.0, 'close': 24998.78}
# {'date': '2023-03-17', 'open': 24998.78, 'high': 27756.84, 'low': 24890.0, 'close': 27395.13}
# {'date': '2023-03-18', 'open': 27395.13, 'high': 27724.85, 'low': 26578.0, 'close': 26907.49}
# {'date': '2023-03-19', 'open': 26907.49, 'high': 28390.1, 'low': 26827.22, 'close': 27972.87}
# {'date': '2023-03-20', 'open': 27972.87, 'high': 28472.0, 'low': 27124.47, 'close': 27717.01}
# {'date': '2023-03-21', 'open': 27717.01, 'high': 28438.55, 'low': 27303.1, 'close': 28105.47}
# {'date': '2023-03-22', 'open': 28107.81, 'high': 28868.05, 'low': 26601.8, 'close': 27250.97}
# {'date': '2023-03-23', 'open': 27250.97, 'high': 28750.0, 'low': 27105.0, 'close': 28295.41}
# {'date': '2025-11-23', 'open': 84739.75, 'high': 88127.64, 'low': 84667.57, 'close': 86830.0}
# {'date': '2025-11-24', 'open': 86830.0, 'high': 89228.0, 'low': 85272.0, 'close': 88300.01}
# {'date': '2025-11-25', 'open': 88300.01, 'high': 88519.99, 'low': 86116.0, 'close': 87369.96}
# {'date': '2025-11-26', 'open': 87369.97, 'high': 90656.08, 'low': 86306.77, 'close': 90484.02}
# {'date': '2025-11-27', 'open': 90484.01, 'high': 91950.0, 'low': 90089.91, 'close': 91333.95}
# {'date': '2025-11-28', 'open': 91333.94, 'high': 93092.0, 'low': 90180.63, 'close': 90890.7}
# {'date': '2025-11-29', 'open': 90890.71, 'high': 91165.65, 'low': 90155.47, 'close': 90802.44}
# {'date': '2025-11-30', 'open': 90802.44, 'high': 92000.01, 'low': 90336.9, 'close': 90360.0}
# {'date': '2025-12-01', 'open': 90360.01, 'high': 90417.0, 'low': 83822.76, 'close': 86286.01}
# {'date': '2025-12-02', 'open': 86286.01, 'high': 92307.65, 'low': 86184.39, 'close': 91277.88}
# {'date': '2025-12-03', 'open': 91277.88, 'high': 94150.0, 'low': 90990.23, 'close': 93429.95}
# {'date': '2025-12-04', 'open': 93429.95, 'high': 94080.0, 'low': 90889.0, 'close': 92078.06}
# {'date': '2025-12-05', 'open': 92078.06, 'high': 92692.36, 'low': 88056.0, 'close': 89330.04}
# {'date': '2025-12-06', 'open': 89330.04, 'high': 90289.97, 'low': 88908.01, 'close': 89236.79}
# {'date': '2025-12-07', 'open': 89236.8, 'high': 91760.0, 'low': 87719.28, 'close': 90395.31}
# {'date': '2025-12-08', 'open': 90395.32, 'high': 92287.15, 'low': 89860.0, 'close': 92012.32}

# %%
import yfinance as yf

# yfinance aggira i blocchi perché simula un browser che visita il sito
# Non ha limiti "hard" sugli anni passati
btc = yf.download(["BTC-USD","ETH-USD"], start="2021-01-01", end="2025-12-08")
# Out:
# C:\Users\tomma\AppData\Local\Temp\ipykernel_15556\3098547809.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc = yf.download(["BTC-USD","ETH-USD"], start="2021-01-01", end="2025-12-08")
# [*********************100%***********************]  2 of 2 completed

# %%
df = pd.DataFrame(btc) # Convert into DataFrame
print(df.columns)
df.head()
# Out:
# MultiIndex([( 'Close', 'BTC-USD'),
#             ( 'Close', 'ETH-USD'),
#             (  'High', 'BTC-USD'),
#             (  'High', 'ETH-USD'),
#             (   'Low', 'BTC-USD'),
#             (   'Low', 'ETH-USD'),
#             (  'Open', 'BTC-USD'),
#             (  'Open', 'ETH-USD'),
#             ('Volume', 'BTC-USD'),
#             ('Volume', 'ETH-USD')],
#            names=['Price', 'Ticker'])
# Price              Close                       High               \
# Ticker           BTC-USD      ETH-USD       BTC-USD      ETH-USD
# Date
# 2021-01-01  29374.152344   730.367554  29600.626953   749.201843
# 2021-01-02  32127.267578   774.534973  33155.117188   786.798462
# 2021-01-03  32782.023438   975.507690  34608.558594  1006.565002
# 2021-01-04  31971.914062  1040.233032  33440.218750  1153.189209
# 2021-01-05  33992.429688  1100.006104  34437.589844  1129.371460
#
# Price                Low                      Open                    Volume  \
# Ticker           BTC-USD     ETH-USD       BTC-USD      ETH-USD      BTC-USD
# Date
# 2021-01-01  28803.585938  719.792236  28994.009766   737.708374  40730301359
# 2021-01-02  29091.181641  718.109497  29376.455078   730.402649  67865420765
# 2021-01-03  32052.316406  771.561646  32129.408203   774.511841  78665235202
# 2021-01-04  28722.755859  912.305359  32810.949219   977.058838  81163475344
# 2021-01-05  30221.187500  986.811279  31977.041016  1041.498779  67547324782
#
# Price
# Ticker          ETH-USD
# Date
# 2021-01-01  13652004358
# 2021-01-02  19740771179
# 2021-01-03  45200463368
# 2021-01-04  56945985763
# 2021-01-05  41535932781

# %%
df.isna().sum() # There is no Missing Values
# Out:
# Price   Ticker
# Close   BTC-USD    0
#         ETH-USD    0
# High    BTC-USD    0
#         ETH-USD    0
# Low     BTC-USD    0
#         ETH-USD    0
# Open    BTC-USD    0
#         ETH-USD    0
# Volume  BTC-USD    0
#         ETH-USD    0
# dtype: int64

# %%
plt.figure()
plt.plot(df.index,df['Close']['BTC-USD'])
plt.title("Bitcoin daily close")
plt.show()
plt.figure()
plt.plot(df.index,df['Close']['ETH-USD'])
plt.title("Etherium daily close")
plt.show()

# %% [markdown]
# ### NyTimes article:

# %%
key = os.getenv("NY_KEY") # your api key
query = 'Bitcoin'
i = 0
url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={query}&page={i}&api-key={key}'

# %%
nyresponse = requests.get(url).json()
nyresponse
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2025 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Bitcoin has plunged more than 30 percent and Ether is down around 40 percent in recent months, as gains from President Trump’s pro-crypto policies evaporated.',
#     'byline': {'original': 'By David Yaffe-Bellany and Kailyn Rhone'},
#     'document_type': 'article',
#     'headline': {'main': 'Those Sky-High Bitcoin Prices Everyone Said Were Here to Stay? They Left.',
#      'kicker': '',
#      'print_headline': 'Those Sky-High Prices Forecast for Bitcoin? They Didn’t Pan Out.'},
#     '_id': 'nyt://article/8e021b81-4ea1-5475-b807-1ae1c42219b5',
#     'keywords': [{'name': 'Subject', 'value': 'Virtual Currency', 'rank': 1},
#      {'name': 'Subject',
#       'value': 'United States Politics and Government',
#       'rank': 2},
#      {'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 3},
#      {'name': 'Subject',
#       'value': 'Regulation and Deregulation of Industry',
#       'rank': 4},
#      {'name': 'Subject',
#       'value': 'Banking and Financial Institutions',
#       'rank': 5},
#      {'name': 'Organization', 'value': 'World Liberty Financial', 'rank': 6},
#      {'name': 'Person', 'value': 'Saylor, Michael J', 'rank': 7},
#      {'name': 'Person', 'value': 'Trump, Donald J', 'rank': 8},
#      {'name': 'Subject', 'value': 'United States Economy', 'rank': 9}],
#     'multimedia': {'caption': '',
#      'credit': 'The New York Times',
#      'default': {'url': 'https://static01.nyt.com/images/2025/12/02/multimedia/2025-biz-standalone-promos-new-2025-12-02-bitcoin-price/2025-biz-standalone-promos-new-2025-12-02-bitcoin-price-articleLarge-v12.png',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/12/02/multimedia/2025-biz-standalone-promos-new-2025-12-02-bitcoin-price/2025-biz-standalone-promos-new-2025-12-02-bitcoin-price-thumbStandard-v12.png',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '1',
#     'print_section': 'B',
#     'pub_date': '2025-12-03T10:02:24Z',
#     'section_name': 'Technology',
#     'snippet': 'Bitcoin has plunged more than 30 percent and Ether is down around 40 percent in recent months, as gains from President Trump’s pro-crypto policies evaporated.',
#     'source': 'The New York Times',
#     'subsection_name': '',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/8e021b81-4ea1-5475-b807-1ae1c42219b5',
#     'web_url': 'https://www.nytimes.com/2025/12/03/technology/cryptocurrencies-tumble-trump-rally.html',
#     'word_count': 798},
#    {'abstract': 'Larry Fink and Brian Armstrong haven’t always agreed on crypto, but the business leaders’ embrace of the asset has helped bring it into the mainstream.',
#     'byline': {'original': 'By Niko Gallogly'},
#     'document_type': 'article',
#     'headline': {'main': 'The Chiefs of BlackRock and Coinbase Dismiss Fears of a Coming Crypto Winter',
#      'kicker': '',
#      'print_headline': ''},
#     '_id': 'nyt://article/6c77ed6c-5b89-53d5-a7df-6ff236554cad',
#     'keywords': [{'name': 'Subject', 'value': 'Virtual Currency', 'rank': 1},
#      {'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 2},
#      {'name': 'Subject',
#       'value': 'Regulation and Deregulation of Industry',
#       'rank': 3},
#      {'name': 'Organization', 'value': 'BlackRock Inc', 'rank': 4},
#      {'name': 'Organization', 'value': 'Coinbase Inc', 'rank': 5},
#      {'name': 'Person', 'value': 'Armstrong, Brian (1983- )', 'rank': 6},
#      {'name': 'Person', 'value': 'Fink, Laurence D', 'rank': 7}],
#     'multimedia': {'caption': 'Andrew Ross Sorkin speaking to Brian Armstrong, chief executive of Coinbase, and Larry Fink, the chief executive of BlackRock.',
#      'credit': 'Karsten Moran for The New York Times',
#      'default': {'url': 'https://static01.nyt.com/images/2025/12/03/multimedia/03dealbook-summit-armstrong-fink-wckh/03dealbook-summit-armstrong-fink-wckh-articleLarge.jpg',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/12/03/multimedia/03dealbook-summit-armstrong-fink-wckh/03dealbook-summit-armstrong-fink-wckh-thumbStandard.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '',
#     'print_section': '',
#     'pub_date': '2025-12-03T17:09:19Z',
#     'section_name': 'Business',
#     'snippet': 'Larry Fink and Brian Armstrong haven’t always agreed on crypto, but the business leaders’ embrace of the asset has helped bring it into the mainstream.',
#     'source': 'The New York Times',
#     'subsection_name': 'DealBook',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/6c77ed6c-5b89-53d5-a7df-6ff236554cad',
#     'web_url': 'https://www.nytimes.com/2025/12/03/business/dealbook/blackrock-coinbase-crypto-dealbook-summit.html',
#     'word_count': 406},
#    {'abstract': 'Bitcoin and other digital tokens have lost more than $1 trillion in value in recent weeks, raising concerns about a wider market fallout.',
#     'byline': {'original': 'By Andrew Ross Sorkin, Bernhard Warner, Sarah Kessler, Michael J. de la Merced, Niko Gallogly, Brian O’Keefe, Ian Mount and Grady McGregor'},
#     'document_type': 'article',
#     'headline': {'main': 'Why Crypto’s Slide Is Rattling Wall Street',
#      'kicker': 'DealBook Newsletter',
#      'print_headline': ''},
#     '_id': 'nyt://article/9d6dfc10-5852-51b1-a582-4b263d677068',
#     'keywords': [{'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 2},
#      {'name': 'Subject', 'value': 'Stocks and Bonds', 'rank': 3},
#      {'name': 'Subject', 'value': 'Exchange Traded Funds', 'rank': 4},
#      {'name': 'Organization', 'value': 'BlackRock Inc', 'rank': 5},
#      {'name': 'Organization', 'value': 'Fidelity Investments', 'rank': 6}],
#     'multimedia': {'caption': 'A recent slump in crypto prices has rattled investors.',
#      'credit': 'Gabriela Bhaskar/The New York Times',
#      'default': {'url': 'https://static01.nyt.com/images/2025/11/24/multimedia/24db-btc-wcqh/24db-btc-wcqh-articleLarge.jpg',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/11/24/multimedia/24db-btc-wcqh/24db-btc-wcqh-thumbStandard.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '',
#     'print_section': '',
#     'pub_date': '2025-11-24T13:04:58Z',
#     'section_name': 'Business',
#     'snippet': 'Bitcoin and other digital tokens have lost more than $1 trillion in value in recent weeks, raising concerns about a wider market fallout.',
#     'source': 'The New York Times',
#     'subsection_name': 'DealBook',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/9d6dfc10-5852-51b1-a582-4b263d677068',
#     'web_url': 'https://www.nytimes.com/2025/11/24/business/dealbook/bitcoin-crypto-wall-street.html',
#     'word_count': 1977},
#    {'abstract': 'Escaping zipties, hiring bodyguards and other practical lessons in self-defense for crypto traders, after a series of gruesome crimes spooked the community.',
#     'byline': {'original': 'By David Yaffe-Bellany and Maurizio Fiorino'},
#     'document_type': 'article',
#     'headline': {'main': 'How to Not Get Kidnapped for Your Bitcoin',
#      'kicker': '',
#      'print_headline': 'Bitcoin Investors’ New Worry: Kidnappers'},
#     '_id': 'nyt://article/df870ae5-b979-511d-a198-b247d7f0721c',
#     'keywords': [{'name': 'Subject',
#       'value': 'audio-neutral-informative',
#       'rank': 1},
#      {'name': 'Subject', 'value': 'Virtual Currency', 'rank': 2},
#      {'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 3},
#      {'name': 'Subject', 'value': 'Kidnapping and Hostages', 'rank': 4},
#      {'name': 'Subject', 'value': 'Robberies and Thefts', 'rank': 5},
#      {'name': 'Subject', 'value': 'Assaults', 'rank': 6},
#      {'name': 'Subject', 'value': 'Self-Defense', 'rank': 7},
#      {'name': 'Subject',
#       'value': 'Conventions, Fairs and Trade Shows',
#       'rank': 8}],
#     'multimedia': {'caption': 'Kevin Harris, a security consultant, pushing a metal tool into a ziptie during a training workshop in Switzerland.',
#      'credit': 'Maurizio Fiorino for The New York Times',
#      'default': {'url': 'https://static01.nyt.com/images/2025/11/23/multimedia/17biz-crypto-abduction-20-kpjc/17biz-crypto-abduction-20-kpjc-articleLarge.jpg',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/11/23/multimedia/17biz-crypto-abduction-20-kpjc/17biz-crypto-abduction-20-kpjc-thumbStandard-v2.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'SundayBusiness',
#     'print_page': '4',
#     'print_section': 'BU',
#     'pub_date': '2025-11-17T05:01:20Z',
#     'section_name': 'Business',
#     'snippet': 'Escaping zipties, hiring bodyguards and other practical lessons in self-defense for crypto traders, after a series of gruesome crimes spooked the community.',
#     'source': 'The New York Times',
#     'subsection_name': '',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/df870ae5-b979-511d-a198-b247d7f0721c',
#     'web_url': 'https://www.nytimes.com/2025/11/17/business/how-to-not-get-kidnapped-for-your-bitcoin.html',
#     'word_count': 1374},
#    {'abstract': 'The debut of American Bitcoin, a mining firm backed by Eric Trump and Donald Trump Jr., has heightened the ethical concerns swirling around the Trump presidency.',
#     'byline': {'original': 'By David Yaffe-Bellany'},
#     'document_type': 'article',
#     'headline': {'main': 'The Trumps Promote a New Crypto Venture: Bitcoin Mining',
#      'kicker': '',
#      'print_headline': 'The Trumps Promote  Bitcoin Mining Venture'},
#     '_id': 'nyt://article/4328968d-d778-573a-a3bc-561edbd600b4',
#     'keywords': [{'name': 'Subject',
#       'value': 'United States Politics and Government',
#       'rank': 1},
#      {'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 2},
#      {'name': 'Subject', 'value': 'Virtual Currency', 'rank': 3},
#      {'name': 'Subject', 'value': 'Conflicts of Interest', 'rank': 4},
#      {'name': 'Subject',
#       'value': 'Regulation and Deregulation of Industry',
#       'rank': 5},
#      {'name': 'Subject', 'value': 'Customs (Tariff)', 'rank': 6},
#      {'name': 'Organization', 'value': 'American Bitcoin Corp', 'rank': 7},
#      {'name': 'Organization', 'value': 'Bitmain Technologies Ltd', 'rank': 8},
#      {'name': 'Person', 'value': 'Trump, Donald J', 'rank': 9},
#      {'name': 'Person', 'value': 'Trump, Donald J Jr', 'rank': 10},
#      {'name': 'Person', 'value': 'Trump, Eric F (1984- )', 'rank': 11},
#      {'name': 'Location', 'value': 'China', 'rank': 12}],
#     'multimedia': {'caption': 'Eric Trump spoke on a panel with his brother Donald Trump Jr. at Bitcoin 2025 in Las Vegas last month.',
#      'credit': 'Gabriela Bhaskar/The New York Times',
#      'default': {'url': 'https://static01.nyt.com/images/2025/06/12/multimedia/00biz-american-bitcoin-cqhz/00biz-american-bitcoin-cqhz-articleLarge.jpg',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/06/12/multimedia/00biz-american-bitcoin-cqhz/00biz-american-bitcoin-cqhz-thumbStandard.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '1',
#     'print_section': 'B',
#     'pub_date': '2025-06-16T15:07:17Z',
#     'section_name': 'Technology',
#     'snippet': 'The debut of American Bitcoin, a mining firm backed by Eric Trump and Donald Trump Jr., has heightened the ethical concerns swirling around the Trump presidency.',
#     'source': 'The New York Times',
#     'subsection_name': '',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/4328968d-d778-573a-a3bc-561edbd600b4',
#     'web_url': 'https://www.nytimes.com/2025/06/16/technology/trump-american-bitcoin-mining.html',
#     'word_count': 1432},
#    {'abstract': 'American Bitcoin, a cryptocurrency firm co-founded by Eric Trump, said it was merging with a company traded on the Nasdaq, the latest expansion of the family’s investments in crypto.',
#     'byline': {'original': 'By David Yaffe-Bellany and Kenneth P. Vogel'},
#     'document_type': 'article',
#     'headline': {'main': 'Trump Family Bitcoin Company Announces Plan to Go Public',
#      'kicker': '',
#      'print_headline': ''},
#     '_id': 'nyt://article/eddfa4c8-5f11-59cf-b94c-7de09dfe66df',
#     'keywords': [{'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 1},
#      {'name': 'Subject',
#       'value': 'United States Politics and Government',
#       'rank': 2},
#      {'name': 'Organization', 'value': 'American Bitcoin Corp', 'rank': 3},
#      {'name': 'Organization', 'value': 'World Liberty Financial', 'rank': 4},
#      {'name': 'Person', 'value': 'Trump, Donald J', 'rank': 5},
#      {'name': 'Person', 'value': 'Trump, Donald J Jr', 'rank': 6},
#      {'name': 'Person', 'value': 'Trump, Eric F (1984- )', 'rank': 7}],
#     'multimedia': {'caption': 'An attendee at a Bitcoin conference in Abu Dhabi, United Arab Emirates, last year.',
#      'credit': 'Tamir Kalifa for The New York Times',
#      'default': {'url': 'https://static01.nyt.com/images/2025/05/12/multimedia/12dc-trump-bitcoin-gqck/12dc-trump-bitcoin-gqck-articleLarge.jpg',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/05/12/multimedia/12dc-trump-bitcoin-gqck/12dc-trump-bitcoin-gqck-thumbStandard.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '',
#     'print_section': '',
#     'pub_date': '2025-05-12T18:56:48Z',
#     'section_name': 'Business',
#     'snippet': 'American Bitcoin, a cryptocurrency firm co-founded by Eric Trump, said it was merging with a company traded on the Nasdaq, the latest expansion of the family’s investments in crypto.',
#     'source': 'The New York Times',
#     'subsection_name': '',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/eddfa4c8-5f11-59cf-b94c-7de09dfe66df',
#     'web_url': 'https://www.nytimes.com/2025/05/12/business/trump-american-bitcoin-crypto.html',
#     'word_count': 393},
#    {'abstract': 'The kiosks, which resemble conventional A.T.M.s and convert cash into virtual currencies, are increasingly under scrutiny as a tool for scammers.',
#     'byline': {'original': 'By Cameron Fozi, Chloe Rosenberg and Reeno Hashimoto'},
#     'document_type': 'article',
#     'headline': {'main': 'How Fraudsters Use Cryptocurrency A.T.M.s to Target Victims',
#      'kicker': '',
#      'print_headline': 'Cryptocurrency A.T.M.s Under Scrutiny as Scammers Cash Out'},
#     '_id': 'nyt://article/84e85100-890c-5b60-bcb6-009e3f323d9c',
#     'keywords': [{'name': 'Subject', 'value': 'Virtual Currency', 'rank': 1},
#      {'name': 'Subject', 'value': 'State Legislatures', 'rank': 2},
#      {'name': 'Subject', 'value': 'Automated Teller Machines', 'rank': 3},
#      {'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 4},
#      {'name': 'Subject',
#       'value': 'Banking and Financial Institutions',
#       'rank': 5},
#      {'name': 'Subject', 'value': 'Frauds and Swindling', 'rank': 6},
#      {'name': 'Subject', 'value': 'Robberies and Thefts', 'rank': 7},
#      {'name': 'Subject', 'value': 'Computers and the Internet', 'rank': 8},
#      {'name': 'Subject',
#       'value': 'Regulation and Deregulation of Industry',
#       'rank': 9},
#      {'name': 'Organization', 'value': 'Bitcoin Depot', 'rank': 10},
#      {'name': 'Organization', 'value': 'Byte Federal', 'rank': 11},
#      {'name': 'Organization',
#       'value': 'CoinFlip (GPD Holdings LLC)',
#       'rank': 12},
#      {'name': 'Organization', 'value': 'Coinme', 'rank': 13},
#      {'name': 'Organization', 'value': 'Athena Bitcoin', 'rank': 14}],
#     'multimedia': {'caption': 'A Bitcoin A.T.M. in a convenience store in Miami. Crypto A.T.M. operators are in at least 28,000 locations, according to Treasury Department data.',
#      'credit': 'Joe Raedle/Getty Images',
#      'default': {'url': 'https://static01.nyt.com/images/2025/11/17/multimedia/BIZ-CRYPTO-ATM-03-cjqg/BIZ-CRYPTO-ATM-03-cjqg-articleLarge.jpg',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/11/17/multimedia/BIZ-CRYPTO-ATM-03-cjqg/BIZ-CRYPTO-ATM-03-cjqg-thumbStandard.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '1',
#     'print_section': 'B',
#     'pub_date': '2025-11-17T05:01:20Z',
#     'section_name': 'Technology',
#     'snippet': 'The kiosks, which resemble conventional A.T.M.s and convert cash into virtual currencies, are increasingly under scrutiny as a tool for scammers.',
#     'source': 'The New York Times',
#     'subsection_name': '',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/84e85100-890c-5b60-bcb6-009e3f323d9c',
#     'web_url': 'https://www.nytimes.com/2025/11/17/technology/fraudsters-cryptocurrency-atms.html',
#     'word_count': 1208},
#    {'abstract': 'The deal is the latest move by companies partly owned by President Trump and members of his family to invest in crypto currency.',
#     'byline': {'original': 'By Matthew Goldstein'},
#     'document_type': 'article',
#     'headline': {'main': 'Trump Media Raises Money to Buy $2.5 Billion in Bitcoin',
#      'kicker': '',
#      'print_headline': 'Trump Firm To Venture Into Bitcoin'},
#     '_id': 'nyt://article/9a45c688-fec0-538b-92a7-0fcddd68a93a',
#     'keywords': [{'name': 'Subject',
#       'value': 'United States Politics and Government',
#       'rank': 1},
#      {'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 2},
#      {'name': 'Subject', 'value': 'Stocks and Bonds', 'rank': 3},
#      {'name': 'Subject', 'value': 'Politics and Government', 'rank': 4},
#      {'name': 'Organization',
#       'value': 'Trump Media & Technology Group',
#       'rank': 5},
#      {'name': 'Organization',
#       'value': 'Truth Social (Social Network)',
#       'rank': 6},
#      {'name': 'Person', 'value': 'Trump, Donald J', 'rank': 7}],
#     'multimedia': {'caption': 'President Trump and his family have become more involved in a number of crypto companies.',
#      'credit': 'Yuki Iwamura/Bloomberg',
#      'default': {'url': 'https://static01.nyt.com/images/2025/05/27/multimedia/27biz-trumpmedia-bitcoin-01-ptbk/27biz-trumpmedia-bitcoin-01-ptbk-articleLarge.jpg',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/05/27/multimedia/27biz-trumpmedia-bitcoin-01-ptbk/27biz-trumpmedia-bitcoin-01-ptbk-thumbStandard.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '1',
#     'print_section': 'B',
#     'pub_date': '2025-05-27T15:43:30Z',
#     'section_name': 'Business',
#     'snippet': 'The deal is the latest move by companies partly owned by President Trump and members of his family to invest in crypto currency.',
#     'source': 'The New York Times',
#     'subsection_name': '',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/9a45c688-fec0-538b-92a7-0fcddd68a93a',
#     'web_url': 'https://www.nytimes.com/2025/05/27/business/trump-media-bitcoin.html',
#     'word_count': 880},
#    {'abstract': 'In the Trump administration’s latest example of dialing back cryptocurrency enforcement, Roger Ver agreed to pay about $48 million to end a tax fraud case.',
#     'byline': {'original': 'By Kenneth P. Vogel and David Yaffe-Bellany'},
#     'document_type': 'article',
#     'headline': {'main': 'Crypto Investor Known as ‘Bitcoin Jesus’ Reaches Deal With Prosecutors',
#      'kicker': '',
#      'print_headline': 'Crypto Investor Will Pay To Settle Tax Fraud Case'},
#     '_id': 'nyt://article/927fd981-6216-50dd-9f3d-b89fdff7c84c',
#     'keywords': [{'name': 'Subject', 'value': 'Virtual Currency', 'rank': 1},
#      {'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 2},
#      {'name': 'Subject', 'value': 'Tax Evasion', 'rank': 3},
#      {'name': 'Subject',
#       'value': 'Regulation and Deregulation of Industry',
#       'rank': 4},
#      {'name': 'Subject',
#       'value': 'United States Politics and Government',
#       'rank': 5},
#      {'name': 'Organization',
#       'value': 'Securities and Exchange Commission',
#       'rank': 6},
#      {'name': 'Organization', 'value': 'Justice Department', 'rank': 7},
#      {'name': 'Person', 'value': 'Ver, Roger (Bitcoin Jesus)', 'rank': 8},
#      {'name': 'Person', 'value': 'Trump, Donald J', 'rank': 9}],
#     'multimedia': {'caption': 'Roger Ver, shown in 2013, was charged with fraud and tax evasion for failing to pay $48 million in taxes that he owed on his cryptocurrency holdings.',
#      'credit': 'Danny Lee/South China Morning Post, via Getty Images',
#      'default': {'url': 'https://static01.nyt.com/images/2025/10/09/multimedia/09crypto-ver-pclj/09crypto-ver-pclj-articleLarge.jpg',
#       'height': 395,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/10/09/multimedia/09crypto-ver-pclj/09crypto-ver-pclj-thumbStandard.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '4',
#     'print_section': 'B',
#     'pub_date': '2025-10-09T20:09:51Z',
#     'section_name': 'Technology',
#     'snippet': 'In the Trump administration’s latest example of dialing back cryptocurrency enforcement, Roger Ver agreed to pay about $48 million to end a tax fraud case.',
#     'source': 'The New York Times',
#     'subsection_name': '',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/927fd981-6216-50dd-9f3d-b89fdff7c84c',
#     'web_url': 'https://www.nytimes.com/2025/10/09/technology/roger-ver-bitcoin-justice-department-deal.html',
#     'word_count': 628},
#    {'abstract': 'The rapid drop shows that cryptocurrencies, which the president has promoted, are subject to the same market gyrations as any other risky asset.',
#     'byline': {'original': 'By David Yaffe-Bellany'},
#     'document_type': 'article',
#     'headline': {'main': 'Bitcoin Is Down 10% Since Trump’s Global Tariff Announcement',
#      'kicker': '',
#      'print_headline': ''},
#     '_id': 'nyt://article/eb45bca9-4afd-538b-8393-aee0a5fda877',
#     'keywords': [{'name': 'Subject', 'value': 'Bitcoin (Currency)', 'rank': 1},
#      {'name': 'Subject', 'value': 'Virtual Currency', 'rank': 2},
#      {'name': 'Subject',
#       'value': 'International Trade and World Market',
#       'rank': 3},
#      {'name': 'Subject',
#       'value': 'Prices (Fares, Fees and Rates)',
#       'rank': 4}],
#     'multimedia': {'caption': 'Bitcoin at a cryptocurrency exchange.',
#      'credit': 'Dale De La Rey/Agence France-Presse — Getty Images',
#      'default': {'url': 'https://static01.nyt.com/images/2025/04/07/multimedia/07markets-tariffs-crypto-jvlb/07markets-tariffs-crypto-jvlb-articleLarge.jpg',
#       'height': 400,
#       'width': 600},
#      'thumbnail': {'url': 'https://static01.nyt.com/images/2025/04/07/multimedia/07markets-tariffs-crypto-jvlb/07markets-tariffs-crypto-jvlb-thumbStandard.jpg',
#       'height': 75,
#       'width': 75}},
#     'news_desk': 'Business',
#     'print_page': '',
#     'print_section': '',
#     'pub_date': '2025-04-07T02:37:00Z',
#     'section_name': 'Business',
#     'snippet': 'The rapid drop shows that cryptocurrencies, which the president has promoted, are subject to the same market gyrations as any other risky asset.',
#     'source': 'The New York Times',
#     'subsection_name': 'Economy',
#     'type_of_material': 'News',
#     'uri': 'nyt://article/eb45bca9-4afd-538b-8393-aee0a5fda877',
#     'web_url': 'https://www.nytimes.com/2025/04/06/business/economy/trump-bitcoin-crypto-tariffs.html',
#     'word_count': 262}],
#   'metadata': {'hits': 3125, 'offset': 0, 'time': 184}}}

# %%
len(nyresponse["response"]["docs"])
# Out:
# 10

# %%
i = 1
url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={query}&page={i}&api-key={key}'

# %%
nyresponse = requests.get(url).json()

nyresponse

with open("nytimes.json", "w", encoding="utf-8") as f:
    json.dump(nyresponse, f, ensure_ascii=False, indent=4)

# %%
key = os.getenv("NY_KEY")
query = 'crypto'
i = 0
url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={query}&page={i}&api-key={key}'

nyresponse = requests.get(url).json()

nyresponse
# Out:
# {'fault': {'faultstring': 'Invalid ApiKey',
#   'detail': {'errorcode': 'oauth.v2.InvalidApiKey'}}}

# %%
# Definition of the Kafka Producer:

producer = KafkaProducer(
    bootstrap_servers="localhost:9092",
    value_serializer=lambda v: json.dumps(v).encode("utf-8")
)

# %% [markdown]
# 1. **Data retrieval from the New York Times API**
#    - Uses the API key stored in the environment variable `NY_KEY`.
#    - Searches for the queries `"Bitcoin"` and `"Crypto"`.
#    - Iterates through 100 pages of results for each query.
#
# 2. **Request and error handling**
#    - Each HTTP request is executed using `requests.get`.
#    - The response status is checked with `raise_for_status()` to catch any HTTP errors.
#    - In case of an error (e.g., `429 Too Many Requests`, timeout, connection issues), the error is logged and the loop continues with the next request.
#
# 3. **Sending data to Kafka**
#    - If the response is valid, the JSON data is sent to a Kafka topic corresponding to the query (`Bitcoin` or `Crypto`).
#    - This allows real-time processing or storage of the data via a Kafka consumer.
#
# 4. **Rate limit management**
#    - After each request, the script waits 15 seconds (`time.sleep(15)`) to avoid exceeding NYT API limits, reducing the risk of `429 Too Many Requests` errors.
#
# **Note:** The script is designed to safely scrape data while respecting the NYT API's per-minute and daily limits, sending the collected data to Kafka for further processing.

# %%
key = os.getenv("NY_KEY") # your key
query = ["Bitcoin", "Crypto"] # search for Bitcoin and Crypto in general
for i in range(100): # Set 100 pages
    for q in query: # one call for each query
        url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={query}&page={i}&api-key={key}' # update url 

        try:
            response = requests.get(url)
            response.raise_for_status()  # raise error for non-200 responses
            
            data = response.json()

            TOPIC = q

            # send only if the response is valid
            producer.send(TOPIC, data)
            print(f"Send result for '{q}', page {i}")

        except Exception as e: 
            print(f"Error in ='{q}', page={i}: {e}")
            continue  # skip

        time.sleep(15)
# Out:
# Send result for 'Bitcoin', page 0
# Send result for 'Crypto', page 0
# Send result for 'Bitcoin', page 1
# Send result for 'Crypto', page 1
# Send result for 'Bitcoin', page 2
# Send result for 'Crypto', page 2
# Send result for 'Bitcoin', page 3
# Send result for 'Crypto', page 3
# Send result for 'Bitcoin', page 4
# Send result for 'Crypto', page 4
# Send result for 'Bitcoin', page 5
# Send result for 'Crypto', page 5
# Send result for 'Bitcoin', page 6
# Send result for 'Crypto', page 6
# Send result for 'Bitcoin', page 7
# Send result for 'Crypto', page 7
# Send result for 'Bitcoin', page 8
# Send result for 'Crypto', page 8
# Send result for 'Bitcoin', page 9
# Send result for 'Crypto', page 9
# Send result for 'Bitcoin', page 10
# Send result for 'Crypto', page 10
# Send result for 'Bitcoin', page 11
# Send result for 'Crypto', page 11
# Send result for 'Bitcoin', page 12
# Send result for 'Crypto', page 12
# Send result for 'Bitcoin', page 13
# Send result for 'Crypto', page 13
# Send result for 'Bitcoin', page 14
# Send result for 'Crypto', page 14
# Send result for 'Bitcoin', page 15
# Send result for 'Crypto', page 15
# Send result for 'Bitcoin', page 16
# Send result for 'Crypto', page 16
# Send result for 'Bitcoin', page 17
# Send result for 'Crypto', page 17
# Send result for 'Bitcoin', page 18
# Send result for 'Crypto', page 18
# Send result for 'Bitcoin', page 19
# Send result for 'Crypto', page 19
# Send result for 'Bitcoin', page 20
# Send result for 'Crypto', page 65
# Send result for 'Bitcoin', page 66
# Send result for 'Crypto', page 66
# Send result for 'Bitcoin', page 67
# Send result for 'Crypto', page 67
# Send result for 'Bitcoin', page 68
# Send result for 'Crypto', page 68
# Send result for 'Bitcoin', page 69
# Send result for 'Crypto', page 69
# Send result for 'Bitcoin', page 70
# Send result for 'Crypto', page 70
# Send result for 'Bitcoin', page 71
# Send result for 'Crypto', page 71
# Send result for 'Bitcoin', page 72
# Send result for 'Crypto', page 72
# Send result for 'Bitcoin', page 73
# Send result for 'Crypto', page 73
# Send result for 'Bitcoin', page 74
# Send result for 'Crypto', page 74
# Send result for 'Bitcoin', page 75
# Send result for 'Crypto', page 75
# Send result for 'Bitcoin', page 76
# Send result for 'Crypto', page 76
# Send result for 'Bitcoin', page 77
# Send result for 'Crypto', page 77
# Send result for 'Bitcoin', page 78
# Send result for 'Crypto', page 78
# Send result for 'Bitcoin', page 79
# Send result for 'Crypto', page 79
# Send result for 'Bitcoin', page 80
# Send result for 'Crypto', page 80
# Send result for 'Bitcoin', page 81
# Send result for 'Crypto', page 81
# Send result for 'Bitcoin', page 82
# Send result for 'Crypto', page 82
# Send result for 'Bitcoin', page 83
# Send result for 'Crypto', page 83
# Send result for 'Bitcoin', page 84
# Send result for 'Crypto', page 84
# Send result for 'Bitcoin', page 85
# Send result for 'Crypto', page 85
# Send result for 'Bitcoin', page 86
# Send result for 'Crypto', page 86
# Send result for 'Bitcoin', page 87
# Send result for 'Crypto', page 87
# Send result for 'Bitcoin', page 88
# Send result for 'Crypto', page 88
# Send result for 'Bitcoin', page 89
# Send result for 'Crypto', page 89
# Send result for 'Bitcoin', page 90
# Send result for 'Crypto', page 90
# Send result for 'Bitcoin', page 91
# Send result for 'Crypto', page 91
# Send result for 'Bitcoin', page 92
# Send result for 'Crypto', page 92
# Send result for 'Bitcoin', page 93
# Send result for 'Crypto', page 93
# Send result for 'Bitcoin', page 94
# Send result for 'Crypto', page 94
# Send result for 'Bitcoin', page 95
# Send result for 'Crypto', page 95
# Send result for 'Bitcoin', page 96
# Send result for 'Crypto', page 96
# Send result for 'Bitcoin', page 97
# Send result for 'Crypto', page 97
# Send result for 'Bitcoin', page 98
# Send result for 'Crypto', page 98
# Send result for 'Bitcoin', page 99
# Send result for 'Crypto', page 99

# %%
# Prova 2:

# Configura il producer (assicurati di avere il serializer JSON)
producer = KafkaProducer(
    bootstrap_servers=['localhost:9092'],
    value_serializer=lambda x: json.dumps(x).encode('utf-8')
)

key = os.getenv("NY_KEY")
queries = ["Bitcoin", "Crypto"] # Ho rinominato in plurale per chiarezza

print("Inizio scaricamento...")

for i in tqdm(range(100), desc = "Sending Data"): # Per 100 pagine
    for q in queries: # Per ogni parola chiave
        time.sleep(15)
        
        # CORREZIONE 1: Usiamo {q} (la singola parola) e non {query} (la lista intera)
        url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?q={q}&page={i}&api-key={key}'
        
        try:
            response = requests.get(url)
            response.raise_for_status()
            
            data = response.json()
            
            # Estraiamo la lista degli articoli dalla risposta grezza
            articles = data.get('response', {}).get('docs', [])
            
            if not articles:
                print(f"Nessun articolo trovato per '{q}' a pagina {i}")
                continue

            # CORREZIONE 2: Inviamo UN messaggio per OGNI articolo (non tutta la pagina)
            for article in articles:
                
                # Creiamo un dizionario pulito (solo ciò che ti serve)
                clean_doc = {
                    'remote_id': article.get('_id'), # ID univoco del NYT
                    'web_url': article.get('web_url'),
                    'pub_date': article.get('pub_date'),
                    'abstract': article.get('abstract'),
                    'lead_paragraph': article.get('lead_paragraph'),
                    'title': article.get('headline', {}).get('main'),
                    'word_count': article.get('word_count'),
                    'source_query': q # Importante: ci salviamo da quale ricerca arriva!
                }
                
                # Inviamo al topic corrispondente
                # (Puoi usare un topic unico 'articles-topic' o mantenerli separati come fai tu)
                TOPIC = q 
                producer.send(TOPIC, clean_doc)
            
            # Flush per assicurarsi che i messaggi partano subito
            producer.flush() 
            print(f"Inviati {len(articles)} articoli puliti per '{q}', pagina {i}")

        except Exception as e: 
            print(f"Errore in '{q}', pagina={i}: {e}")
            continue

        # Rispetta i limiti dell'API (il NYT è severo, 15 sec va bene)

# %%
producer = KafkaProducer(
    bootstrap_servers=['localhost:9092'],
    value_serializer=lambda x: json.dumps(x).encode('utf-8')
)

# Imposta il periodo storico
start_date = date(2018, 1, 1)
end_date = date(2024, 12, 31)
current_date = start_date

DAILY_LIMIT = 490
calls_made = 0

key = os.getenv("NY_KEY")
queries = ["Bitcoin", "Crypto", "Ethereum"]

while current_date < end_date:
    next_month = current_date + relativedelta(months=1)
    
    # Formatta le date per l'API NYT (YYYYMMDD)
    begin_str = current_date.strftime("%Y%m%d")
    end_str = next_month.strftime("%Y%m%d")
    
    print(f"\n--- Analisi periodo: {begin_str} - {end_str} ---")
    
    # MODIFICA 1: Iteriamo prima per Query, poi per Pagine.
    # Questo ci permette di interrompere la paginazione per una query specifica appena finiscono i dati.
    for q in queries:
        print(f"Scaricando articoli per: {q}...")
        
        for page in range(100): # Massimo 100 pagine
            if calls_made >= DAILY_LIMIT:
                print(f"RAGGIUNTO IL LIMITE GIORNALIERO ({calls_made}). Mi fermo.")
                print(f"Ultimo periodo elaborato: {begin_str} - {end_str}, Query: {q}, Pagina: {page}")
                exit()
            try:
                # MODIFICA 2: Corretto q={q} nell'URL (prima era fisso su Bitcoin)
                url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q={q}&begin_date={begin_str}&end_date={end_str}&page={page}&api-key={key}"
                
                response = requests.get(url)
                response.raise_for_status() # Solleva errore se status != 200

                data = response.json()
                articles = data.get('response', {}).get('docs', [])

                # MODIFICA 3: Se non ci sono articoli, interrompiamo il ciclo delle pagine per QUESTA query
                if not articles:
                    print(f"  -> Nessun altro articolo per '{q}' a pagina {page}. Passo alla prossima query.")
                    break 

                # Invio messaggi a Kafka
                for article in articles:
                    clean_doc = {
                        'remote_id': article.get('_id'),
                        'web_url': article.get('web_url'),
                        'pub_date': article.get('pub_date'),
                        'abstract': article.get('abstract'),
                        'lead_paragraph': article.get('lead_paragraph'),
                        'title': article.get('headline', {}).get('main'),
                        'word_count': article.get('word_count'),
                        'source_query': q
                    }
                    
                    producer.send(q, clean_doc) # Usa 'q' come nome del topic (o usa un topic unico)
            
                producer.flush()
                print(f"  -> Inviati {len(articles)} articoli per '{q}' (Pagina {page})")
                
                # Rispetta il rate limit (12 secondi sono prudenziali e sicuri)
                time.sleep(12)
                calls_made += 1

            except Exception as e:
                print(f"  -> Errore con '{q}' a pagina {page}: {e}")
                # Opzionale: se l'errore è grave (es. 429 Too Many Requests), potresti voler fare un break anche qui
                # break 
                time.sleep(12) # Attesa anche in caso di errore per sicurezza
                continue

    # Passa al mese successivo solo dopo aver finito tutte le query per il mese corrente
    current_date = next_month
# Out:
# --- Analisi periodo: 20180101 - 20180201 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 0)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 1)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 2)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 3)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 4)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 5)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 6)
#   -> Inviati 3 articoli per 'Bitcoin' (Pagina 7)
#   -> Nessun altro articolo per 'Bitcoin' a pagina 8. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Inviati 10 articoli per 'Crypto' (Pagina 0)
#   -> Inviati 8 articoli per 'Crypto' (Pagina 1)
#   -> Nessun altro articolo per 'Crypto' a pagina 2. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Errore con 'Ethereum' a pagina 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Ethereum&begin_date=20180101&end_date=20180201&page=0&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Ethereum' a pagina 1: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Ethereum&begin_date=20180101&end_date=20180201&page=1&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Ethereum' a pagina 2. Passo alla prossima query.
#
# --- Analisi periodo: 20180201 - 20180301 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 0)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 1)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 2)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 3)
#   -> Errore con 'Bitcoin' a pagina 4: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180201&end_date=20180301&page=4&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Bitcoin' a pagina 5. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Inviati 10 articoli per 'Crypto' (Pagina 0)
#   -> Inviati 6 articoli per 'Crypto' (Pagina 1)
#   -> Nessun altro articolo per 'Crypto' a pagina 2. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Inviati 4 articoli per 'Ethereum' (Pagina 0)
#   -> Errore con 'Ethereum' a pagina 1: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Ethereum&begin_date=20180201&end_date=20180301&page=1&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Ethereum' a pagina 2. Passo alla prossima query.
#
# --- Analisi periodo: 20180301 - 20180401 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 0)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 1)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 2)
#   -> Inviati 6 articoli per 'Bitcoin' (Pagina 3)
#   -> Errore con 'Bitcoin' a pagina 4: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180301&end_date=20180401&page=4&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Bitcoin' a pagina 5. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Inviati 6 articoli per 'Crypto' (Pagina 0)
#   -> Nessun altro articolo per 'Crypto' a pagina 1. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Inviati 1 articoli per 'Ethereum' (Pagina 0)
#   -> Nessun altro articolo per 'Ethereum' a pagina 1. Passo alla prossima query.
#
# --- Analisi periodo: 20180401 - 20180501 ---
# Scaricando articoli per: Bitcoin...
#   -> Errore con 'Bitcoin' a pagina 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180401&end_date=20180501&page=0&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Bitcoin' a pagina 1: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180401&end_date=20180501&page=1&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Bitcoin' a pagina 2: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180401&end_date=20180501&page=2&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Bitcoin' a pagina 3. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Inviati 3 articoli per 'Crypto' (Pagina 0)
#   -> Nessun altro articolo per 'Crypto' a pagina 1. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Inviati 4 articoli per 'Ethereum' (Pagina 0)
#   -> Nessun altro articolo per 'Ethereum' a pagina 1. Passo alla prossima query.
#
# --- Analisi periodo: 20180501 - 20180601 ---
# Scaricando articoli per: Bitcoin...
#   -> Errore con 'Bitcoin' a pagina 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180501&end_date=20180601&page=0&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Bitcoin' a pagina 1: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180501&end_date=20180601&page=1&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Bitcoin' a pagina 2: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180501&end_date=20180601&page=2&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Inviati 2 articoli per 'Bitcoin' (Pagina 3)
#   -> Nessun altro articolo per 'Bitcoin' a pagina 4. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Inviati 10 articoli per 'Crypto' (Pagina 0)
#   -> Inviati 2 articoli per 'Crypto' (Pagina 1)
#   -> Nessun altro articolo per 'Crypto' a pagina 2. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Errore con 'Ethereum' a pagina 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Ethereum&begin_date=20180501&end_date=20180601&page=0&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Ethereum' a pagina 1. Passo alla prossima query.
#
# --- Analisi periodo: 20180601 - 20180701 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 0)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 1)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 2)
#   -> Inviati 3 articoli per 'Bitcoin' (Pagina 3)
#   -> Errore con 'Bitcoin' a pagina 4: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20180601&end_date=20180701&page=4&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Bitcoin' a pagina 5. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Inviati 10 articoli per 'Crypto' (Pagina 0)
#   -> Inviati 4 articoli per 'Crypto' (Pagina 1)
#   -> Nessun altro articolo per 'Crypto' a pagina 2. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Inviati 9 articoli per 'Ethereum' (Pagina 0)
#   -> Errore con 'Ethereum' a pagina 1: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Ethereum&begin_date=20180601&end_date=20180701&page=1&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Ethereum' a pagina 2: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Ethereum&begin_date=20180601&end_date=20180701&page=2&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Ethereum' a pagina 3. Passo alla prossima query.
#
# --- Analisi periodo: 20180701 - 20180801 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 0)
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 1)
#   -> Inviati 2 articoli per 'Bitcoin' (Pagina 2)
#   -> Nessun altro articolo per 'Bitcoin' a pagina 3. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Errore con 'Crypto' a pagina 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Crypto&begin_date=20180701&end_date=20180801&page=0&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Crypto' a pagina 1: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Crypto&begin_date=20180701&end_date=20180801&page=1&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Crypto' a pagina 2. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Inviati 1 articoli per 'Ethereum' (Pagina 0)
#   -> Nessun altro articolo per 'Ethereum' a pagina 1. Passo alla prossima query.
#
# --- Analisi periodo: 20180801 - 20180901 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 6 articoli per 'Bitcoin' (Pagina 0)
#   -> Nessun altro articolo per 'Bitcoin' a pagina 1. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Errore con 'Crypto' a pagina 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Crypto&begin_date=20180801&end_date=20180901&page=0&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Crypto' a pagina 1: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Crypto&begin_date=20180801&end_date=20180901&page=1&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Crypto' a pagina 2: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Crypto&begin_date=20180801&end_date=20180901&page=2&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Crypto' a pagina 3. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Nessun altro articolo per 'Ethereum' a pagina 0. Passo alla prossima query.
#
# --- Analisi periodo: 20180901 - 20181001 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 0)
#   -> Inviati 8 articoli per 'Bitcoin' (Pagina 1)
#   -> Nessun altro articolo per 'Bitcoin' a pagina 2. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Errore con 'Crypto' a pagina 0: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Crypto&begin_date=20180901&end_date=20181001&page=0&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Crypto' a pagina 1: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Crypto&begin_date=20180901&end_date=20181001&page=1&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Crypto' a pagina 2. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Inviati 2 articoli per 'Ethereum' (Pagina 0)
#   -> Nessun altro articolo per 'Ethereum' a pagina 1. Passo alla prossima query.
#
# --- Analisi periodo: 20181001 - 20181101 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 0)
#   -> Inviati 1 articoli per 'Bitcoin' (Pagina 1)
#   -> Errore con 'Bitcoin' a pagina 2: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20181001&end_date=20181101&page=2&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Errore con 'Bitcoin' a pagina 3: 429 Client Error: Too Many Requests for url: https://api.nytimes.com/svc/search/v2/articlesearch.json?q=Bitcoin&begin_date=20181001&end_date=20181101&page=3&api-key=dztFKPOAl5jkNzSY1U0S86uW1JTRwAaA
#   -> Nessun altro articolo per 'Bitcoin' a pagina 4. Passo alla prossima query.
# Scaricando articoli per: Crypto...
#   -> Inviati 5 articoli per 'Crypto' (Pagina 0)
#   -> Nessun altro articolo per 'Crypto' a pagina 1. Passo alla prossima query.
# Scaricando articoli per: Ethereum...
#   -> Nessun altro articolo per 'Ethereum' a pagina 0. Passo alla prossima query.
#
# --- Analisi periodo: 20181101 - 20181201 ---
# Scaricando articoli per: Bitcoin...
#   -> Inviati 10 articoli per 'Bitcoin' (Pagina 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 70
#      67     print(f"  -> Inviati {len(articles)} articoli per '{q}' (Pagina {page})")
#      69     # Rispetta il rate limit (12 secondi sono prudenziali e sicuri)
# ---> 70     time.sleep(12)
#      71     calls_made += 1
#      73 except Exception as e:
#
# KeyboardInterrupt:

# %%
# Prova 3 con nuovo time limit
import json
import time
import os
import requests
from datetime import date
from dateutil.relativedelta import relativedelta
from kafka import KafkaProducer

# ---------------------------------------------------------
# CONFIGURAZIONE UTENTE
# ---------------------------------------------------------


start_date = date(2018, 1, 1) 
end_date = date(2024, 12, 31)

# ---------------------------------------------------------
# INIZIO CODICE (NON TOCCARE SOTTO QUESTA RIGA)
# ---------------------------------------------------------

# Setup Kafka
producer = KafkaProducer(
    bootstrap_servers=['localhost:9092'],
    value_serializer=lambda x: json.dumps(x).encode('utf-8')
)

DAILY_LIMIT = 480 # Un po' meno di 500 per sicurezza
calls_made = 0

key = os.getenv("NY_KEY")
queries = ["Bitcoin", "Crypto", "Ethereum"]
current_date = start_date

print(f"🚀 AVVIO SCRIPT. Partenza da: {start_date}")

while current_date < end_date:
    next_month = current_date + relativedelta(months=1)
    
    begin_str = current_date.strftime("%Y%m%d")
    end_str = next_month.strftime("%Y%m%d")
    
    print(f"\n📆 --- Analisi mese: {begin_str} - {end_str} ---")
    
    for q in queries:
        print(f"  🔎 Cerco: {q}...")
        
        # Ciclo per le pagine (da 0 a 100)
        for page in range(100): 
            
            # --- CONTROLLO SALVAVITA LIMITI GIORNALIERI ---
            if calls_made >= DAILY_LIMIT:
                print(f"⛔ STOP: RAGGIUNTO IL LIMITE GIORNALIERO ({calls_made} chiamate).")
                print(f"📌 MEMO: Ripartire da Data: {begin_str}, Query: {q}, Pagina: {page}")
                exit() # Chiude il programma completamente
            
            # --- INIZIO LOGICA "TESTARDA" (RETRY) ---
            attempt_success = False
            should_stop_pages = False # Variabile per capire se dobbiamo cambiare query

            while not attempt_success:
                try:
                    url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?q={q}&begin_date={begin_str}&end_date={end_str}&page={page}&api-key={key}"
                    
                    response = requests.get(url)
                    
                    # CASO 1: ERRORE 429 (TROPPE RICHIESTE)
                    if response.status_code == 429:
                        print(f"    ⏳ API intasata (429). Aspetto 70 secondi e RIPROVO la pagina {page}...")
                        time.sleep(70) 
                        continue # Ricomincia il while, riprovando la stessa pagina
                    
                    # Controllo altri errori
                    response.raise_for_status()

                    data = response.json()
                    articles = data.get('response', {}).get('docs', [])

                    # CASO 2: NESSUN ARTICOLO TROVATO (FINE DEL MESE)
                    if not articles:
                        print(f"    ✅ Nessun altro articolo a pagina {page}. Passo alla prossima parola chiave.")
                        attempt_success = True 
                        should_stop_pages = True
                        break # Esce dal while di retry

                    # CASO 3: TUTTO OK -> INVIO A KAFKA
                    for article in articles:
                        clean_doc = {
                            'remote_id': article.get('_id'),
                            'web_url': article.get('web_url'),
                            'pub_date': article.get('pub_date'),
                            'abstract': article.get('abstract'),
                            'lead_paragraph': article.get('lead_paragraph'),
                            'title': article.get('headline', {}).get('main'),
                            'word_count': article.get('word_count'),
                            'source_query': q
                        }
                        producer.send(q, clean_doc)
            
                    producer.flush()
                    print(f"    -> Scaricati {len(articles)} articoli (Pagina {page})")
                    
                    calls_made += 1
                    attempt_success = True # Usciamo dal loop di retry, è andata bene!
                    
                    # Pausa di cortesia tra una pagina e l'altra
                    time.sleep(12) 

                except Exception as e:
                    # CASO 4: ERRORE GENERICO (Internet giù, etc.)
                    print(f"    ❌ Errore imprevisto: {e}")
                    print("    🔄 Riprovo tra 15 secondi...")
                    time.sleep(15)
                    # Non mettiamo 'break', quindi il while ricomincia e riprova all'infinito

            # Se nel ciclo while abbiamo scoperto che gli articoli sono finiti, fermiamo il ciclo delle pagine
            if should_stop_pages:
                break 

    # Passiamo al mese successivo
    current_date = next_month

# %% [markdown]
# 1. **Kafka Consumers Setup**
#    - Two separate consumers are created:
#      - `consumer_bitcoin` subscribes to the `"Bitcoin"` topic.
#      - `consumer_crypto` subscribes to the `"Crypto"` topic.
#    - Both consumers:
#      - Connect to the Kafka broker at `localhost:9092`.
#      - Deserialize messages from JSON using `json.loads`.
#      - Start reading from the earliest available message (`auto_offset_reset="earliest"`) to process past messages.
#      - Use a new consumer group `"debug-group"` to avoid committing offsets from previous runs.
#
# 2. **MongoDB Setup**
#    - Connects to a local MongoDB instance (`mongodb://localhost:27017`).
#    - Uses the database `bitcoin_pr`.
#    - Stores articles in the collection `Article`.
#
# 3. **Message Consumption and Storage**
#    - For each message received from the `"Bitcoin"` topic:
#      - Prints the message.
#      - Adds a `query` field with value `"Bitcoin"`.
#      - Inserts the document into the MongoDB collection.
#    - For each message received from the `"Crypto"` topic:
#      - Prints the message.
#      - Adds a `query` field with value `"Crypto"`.
#      - Inserts the document into MongoDB.
#
# 4. **Notes**
#    - Using `auto_offset_reset="earliest"` allows the consumer to read **all previous messages** in the topic, which is useful for debugging or reprocessing data.
#    - Each consumer runs in a blocking loop, continuously waiting for new messages.
#    - Ensure MongoDB is running locally before executing the script.

# %%
consumer_bitcoin = KafkaConsumer(
    "Bitcoin",
    bootstrap_servers="localhost:9092",
    value_deserializer=lambda v: json.loads(v.decode("utf-8")),
    auto_offset_reset="earliest",   # <--- importante per vedere i messaggi vecchi
    enable_auto_commit=True,
    group_id="debug-group",          # nuovo group per rileggere da inizio
    consumer_timeout_ms=10000
)

consumer_crypto = KafkaConsumer(
    "Crypto",
    bootstrap_servers="localhost:9092",
    value_deserializer=lambda v: json.loads(v.decode("utf-8")),
    auto_offset_reset="earliest",   # <--- importante per vedere i messaggi vecchi
    enable_auto_commit=True,
    group_id="debug-group-crypto",         # nuovo group per rileggere da inizio
    consumer_timeout_ms=10000
)

consumer_eth = KafkaConsumer(
    "Ethereum",
    bootstrap_servers="localhost:9092",
    value_deserializer=lambda v: json.loads(v.decode("utf-8")),
    auto_offset_reset="earliest",   # <--- importante per vedere i messaggi vecchi
    enable_auto_commit=True,
    group_id="debug-group-crypto",         # nuovo group per rileggere da inizio
    consumer_timeout_ms=10000
)

# %%
client = MongoClient("mongodb://localhost:27017")
 
db = client['bitcoin_project_month']

collection = db['Article']

print("Waiting for Ethereum messages...")
for msg in consumer_eth:
    print("Received:", msg.value)
    doc = msg.value
    doc['query'] = 'Ethereum'
    collection.insert_one(doc)

print("Waiting for Bitcoin messages...")
for msg in consumer_bitcoin:
    print("Received:", msg.value)
    doc = msg.value
    doc['query'] = 'Bitcoin'
    collection.insert_one(doc)

print("Waiting for Crypto messages...")
for msg in consumer_crypto:
    print("Received:", msg.value)
    doc = msg.value
    doc['query'] = 'Crypto'
    collection.insert_one(doc)

print("All messages consumed.")
# Out:
# Waiting for Ethereum messages...
# Received: {'remote_id': 'nyt://article/cda6c13b-26b7-5fa3-a6da-ef82c4df3d42', 'web_url': 'https://www.nytimes.com/2018/02/07/technology/forbes-virtual-currency-billionaires.html', 'pub_date': '2018-02-07T10:00:26Z', 'abstract': 'Forbes published its first list of the wealthiest cryptocurrency holders, even as recent price declines have shrunk the value of their fortunes.', 'lead_paragraph': None, 'title': 'Here Are the World’s Virtual Currency Billionaires (or at Least They Were)', 'word_count': 782, 'source_query': 'Ethereum'}
# Received: {'remote_id': 'nyt://article/59569bf6-26bd-5169-89d9-3157d39b611c', 'web_url': 'https://www.nytimes.com/2018/02/05/business/dealbook/broadcom-qualcomm-bid.html', 'pub_date': '2018-02-05T12:45:47Z', 'abstract': 'Stock investors have endured a number of big drops over past three decades. Monday’s sell-off, on a percentage basis, isn’t close to the worst.', 'lead_paragraph': None, 'title': 'DealBook Briefing: How Monday’s Stock Plunge Ranks?', 'word_count': 3093, 'source_query': 'Ethereum'}
# Received: {'remote_id': 'nyt://article/ec917614-c857-5969-9861-f3b8c38fa861', 'web_url': 'https://www.nytimes.com/2018/02/01/business/dealbook/bitcoin-price-manipulation-bitfinex.html', 'pub_date': '2018-02-01T12:29:50Z', 'abstract': 'Apple reported record profit and sales, Amazon easily beat expectations, and Google-parent Alphabet posted a loss because of the new tax law.', 'lead_paragraph': None, 'title': 'Apple, Alphabet, Amazon Reported Results. Here’s How They Fared: DealBook Briefing', 'word_count': 3644, 'source_query': 'Ethereum'}
# Received: {'remote_id': 'nyt://article/6d661254-5d3e-5d87-aecb-cce5a99c1c9b', 'web_url': 'https://www.nytimes.com/2018/02/06/business/dealbook/stock-market-drops.html', 'pub_date': '2018-02-06T12:31:10Z', 'abstract': 'The owner of The Los Angeles Times is close to a deal to sell the newspaper to Patrick Soon-Shiong, a billionaire Los Angeles doctor.', 'lead_paragraph': None, 'title': 'DealBook Briefing: Tronc Nears Deal to Sell Los Angeles Times', 'word_count': 3937, 'source_query': 'Ethereum'}
# Received: {'remote_id': 'nyt://article/07901bc5-b243-57bf-9b78-b2be296a04f9', 'web_url': 'https://www.nytimes.com/2018/03/04/technology/telegram-initial-coin-offering.html', 'pub_date': '2018-03-04T22:23:37Z', 'abstract': 'It took Facebook seven years to raise its first $1 billion. Thanks to an initial coin offering, it could take the messaging app just four months.', 'lead_paragraph': None, 'title': 'Virtual Currency Offerings May Hit a New Peak with Telegram Coin Sale', 'word_count': 1337, 'source_query': 'Ethereum'}
# Received: {'remote_id': 'nyt://article
 'source_query': 'Bitcoin'}
# Received: {'remote_id': 'nyt://article/5b62468a-563c-58c3-b9a9-71e83aaa1aee', 'web_url': 'https://www.nytimes.com/2021/10/15/podcasts/transcript-ezra-klein-interviews-katie-haun.html', 'pub_date': '2021-10-15T17:30:44Z', 'abstract': 'A conversation about the future of crypto', 'lead_paragraph': None, 'title': 'Transcript: Ezra Klein Interviews Katie Haun', 'word_count': 13296, 'source_query': 'Bitcoin'}
# Received: {'remote_id': 'nyt://article/fbb41c48-d88d-5ae2-8295-bf7f758bb52b', 'web_url': 'https://www.nytimes.com/live/2021/10/04/business/news-business-stock-market/a-costly-bug-reveals-the-limits-of-the-crypto-industrys-decentralization-claims', 'pub_date': '2021-10-04T14:09:48Z', 'abstract': '', 'lead_paragraph': None, 'title': 'A costly bug reveals the limits of the crypto industry’s decentralization claims.', 'word_count': 291, 'source_query': 'Bitcoin'}
# Received: {'remote_id': 'nyt://article/406d92d7-ce69-5ec6-bf87-72628bc64a88', 'web_url': 'https://www.nytimes.com/2021/10/09/business/dealbook/michael-dell-book.html', 'pub_date': '2021-10-09T12:00:04Z', 'abstract': 'In “Play Nice But Win,” Mr. Dell delves into the drama behind some of the biggest deals of the past decade.', 'lead_paragraph': None, 'title': 'Michael Dell Is Trying to Be Nice', 'word_count': 1223, 'source_query': 'Bitcoin'}
# Received: {'remote_id': 'nyt://article/8d1e8c5c-796a-5358-8b0c-4e8932f95599', 'web_url': 'https://www.nytimes.com/2021/10/20/business/dealbook/dealbook-summit-cook-barra-mcconaughey.html', 'pub_date': '2021-10-20T11:11:31Z', 'abstract': 'Tim Cook, Mary Barra and Matthew McConaughey are among the headliners.', 'lead_paragraph': None, 'title': 'Meet the Lineup for the DealBook Online Summit', 'word_count': 1804, 'source_query': 'Bitcoin'}
# Waiting for Crypto messages...
# All messages consumed.

# %%
client = MongoClient("mongodb://localhost:27017")

db = client['bitcoin_project_month'] 

collection = db['Article']

# %%
pipeline = [
    {
        "$group": {
            "_id": "$web_url",  # Sostituisci con il campo che identifica l'univocità (es. id, url, title)
            "count": {"$sum": 1},
            "docs": {"$push": "$_id"} # Opzionale: salva gli ID di Mongo dei duplicati
        }
    },
    {
        "$match": {
            "count": {"$gt": 1} # Filtra solo quelli che compaiono più di una volta
        }
    }
]

duplicati = list(collection.aggregate(pipeline))

print(f"Trovati {len(duplicati)} articoli duplicati.")

for d in duplicati[:5]: # Stampa i primi 5 esempi
    print(f"L'URL {d['_id']} appare {d['count']} volte.")
# Out:
# Trovati 311 articoli duplicati.
# L'URL https://www.nytimes.com/2021/02/24/arts/design/christies-beeple-nft.html appare 2 volte.
# L'URL https://www.nytimes.com/2018/07/29/technology/cryptocurrency-bermuda-malta-gibraltar.html appare 2 volte.
# L'URL https://www.nytimes.com/2018/11/22/world/middleeast/israel-us-ashkelon-hacker.html appare 2 volte.
# L'URL https://www.nytimes.com/2018/06/27/business/dealbook/governments-blockchains-services.html appare 2 volte.
# L'URL https://www.nytimes.com/2018/06/14/business/dealbook/comcast-disney-fox.html appare 2 volte.

# %%
# DEDUPLICATION:

duplicati = list(collection.aggregate(pipeline))
print(f"Trovati {len(duplicati)} URL con duplicati.")

# Lista per accumulare tutti gli _id da cancellare
ids_da_cancellare = []

for d in duplicati:
    # d['docs'] è una lista di tutti gli _id che hanno lo stesso URL.
    # d['docs'][0] è quello che SALVIAMO (il primo).
    # d['docs'][1:] sono quelli che ELIMINIAMO (dal secondo in poi).
    ids_da_cancellare.extend(d['docs'][1:])

# Verifica di sicurezza
if ids_da_cancellare:
    print(f"Sto per eliminare {len(ids_da_cancellare)} documenti duplicati...")
    
    # Esegui l'eliminazione in una sola operazione (molto più veloce di un loop)
    risultato = collection.delete_many({"_id": {"$in": ids_da_cancellare}})
    
    print(f"Operazione completata. Eliminati {risultato.deleted_count} documenti.")
else:
    print("Nessun duplicato da eliminare.")
# Out:
# Trovati 311 URL con duplicati.
# Sto per eliminare 362 documenti duplicati...
# Operazione completata. Eliminati 362 documenti.

# %%
pipeline = [
    {
        "$group": {
            "_id": "$web_url",  # Sostituisci con il campo che identifica l'univocità (es. id, url, title)
            "count": {"$sum": 1},
            "docs": {"$push": "$_id"} # Opzionale: salva gli ID di Mongo dei duplicati
        }
    },
    {
        "$match": {
            "count": {"$gt": 1} # Filtra solo quelli che compaiono più di una volta
        }
    }
]

duplicati = list(collection.aggregate(pipeline))

print(f"Trovati {len(duplicati)} articoli duplicati.")

for d in duplicati[:5]: # Stampa i primi 5 esempi
    print(f"L'URL {d['_id']} appare {d['count']} volte.")
# Out:
# Trovati 0 articoli duplicati.

# %%
num_articles = collection.count_documents({})
print(f"Number of articles in the collection: {num_articles}")
# Conta articoli per query specifica
num_bitcoin = collection.count_documents({'query': 'Bitcoin'})
num_crypto = collection.count_documents({'query': 'Crypto'})
num_ethereum = collection.count_documents({'query': 'Ethereum'})

print(f"Number of Bitcoin articles: {num_bitcoin}")
print(f"Number of Crypto articles: {num_crypto}")
print(f"Number of Ethereum articles: {num_ethereum}")
# Out:
# Number of articles in the collection: 1023
# Number of Bitcoin articles: 920
# Number of Crypto articles: 0
# Number of Ethereum articles: 103

# %%
# istogramma articoli al mese per query
from pymongo import MongoClient
import matplotlib.pyplot as plt
client = MongoClient("mongodb://localhost:27017")
db = client['bitcoin_project_month']
collection = db['Article']
from datetime import datetime
# Funzione per estrarre anno-mese da data di pubblicazione
def extract_year_month(pub_date_str):
    pub_date = datetime.strptime(pub_date_str, "%Y-%m-%dT%H:%M:%S%z")
    return pub_date.strftime("%Y-%m")
# Conta articoli per mese e query
def count_articles_by_month(query):
    pipeline = [
        {"$match": {"query": query}},
        {"$project": {
            "year_month": {
                "$dateToString": {
                    "format": "%Y-%m",
                    "date": {"$toDate": "$pub_date"}
                }
            }
        }},
        {"$group": {
            "_id": "$year_month",
            "count": {"$sum": 1}
        }},
        {"$sort": {"_id": 1}}
    ]
    results = collection.aggregate(pipeline)
    return {res['_id']: res['count'] for res in results}
bitcoin_counts = count_articles_by_month('Bitcoin')
crypto_counts = count_articles_by_month('Crypto')
ethereum_counts = count_articles_by_month('Ethereum')
# Plotting
months = sorted(set(bitcoin_counts.keys()) | set(crypto_counts.keys()) | set(ethereum_counts.keys()))
bitcoin_values = [bitcoin_counts.get(month, 0) for month in months]
crypto_values = [crypto_counts.get(month, 0) for month in months]
ethereum_values = [ethereum_counts.get(month, 0) for month in months]
plt.figure(figsize=(12, 6))
plt.plot(months, bitcoin_values, label='Bitcoin', marker='o')
plt.plot(months, crypto_values, label='Crypto', marker='o')
plt.plot(months, ethereum_values, label='Ethereum', marker='o')
plt.xlabel('Month')
plt.ylabel('Number of Articles')
plt.title('Number of Articles per Month by Query')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Istogramma articoli totali per mese
from pymongo import MongoClient
import matplotlib.pyplot as plt
client = MongoClient("mongodb://localhost:27017")
db = client['bitcoin_project_month']
collection = db['Article']
from datetime import datetime
# Funzione per estrarre anno-mese da data di pubblicazione
def extract_year_month(pub_date_str):
    pub_date = datetime.strptime(pub_date_str, "%Y-%m-%dT%H:%M:%S%z")
    return pub_date.strftime("%Y-%m")
# Conta articoli per mese
def count_articles_by_month():
    pipeline = [
        {"$project": {
            "year_month": {
                "$dateToString": {
                    "format": "%Y-%m",
                    "date": {"$toDate": "$pub_date"}
                }
            }
        }},
        {"$group": {
            "_id": "$year_month",
            "count": {"$sum": 1}
        }},
        {"$sort": {"_id": 1}}
    ]
    results = collection.aggregate(pipeline)
    return {res['_id']: res['count'] for res in results}
monthly_counts = count_articles_by_month()
# Plotting
months = sorted(monthly_counts.keys())
values = [monthly_counts.get(month, 0) for month in months]
plt.figure(figsize=(12, 6))
plt.bar(months, values, color='skyblue')
plt.xlabel('Month')
plt.ylabel('Number of Articles')
plt.title('Total Number of Articles per Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 1. Connessione
client = MongoClient("mongodb://localhost:27017")
db = client['bitcoin_project_month']
collection = db['Article']

# 2. Recupero Dati (SEMPLIFICATO)
# Non serve più l'aggregazione complessa. 
# Chiediamo a Mongo solo il campo 'pub_date' di tutti i documenti.
projection = {"pub_date": 1, "_id": 0}
data = list(collection.find({}, projection))

if not data:
    print("Nessun dato trovato! Assicurati di aver popolato il DB con il nuovo script.")
else:
    # 3. Preparazione DataFrame
    df = pd.DataFrame(data)
    
    # Verifica che la colonna 'pub_date' esista (per sicurezza)
    if 'pub_date' not in df.columns:
        print("ERRORE: Il campo 'pub_date' non è stato trovato nei documenti.")
        print("Esempio di documento nel DB:", collection.find_one())
    else:
        # Conversione data
        df['data'] = pd.to_datetime(df['pub_date'], errors='coerce')
        
        # Rimuove eventuali date non valide (NaT)
        df = df.dropna(subset=['data'])

        # Raggruppa per mese
        df['mese_anno'] = df['data'].dt.to_period('M')
        conteggio_mensile = df['mese_anno'].value_counts().sort_index()

        # Preparazione dati per il grafico
        mesi = conteggio_mensile.index.strftime('%Y-%m') 
        conteggi = conteggio_mensile.values

        # 4. Generazione Grafico (Il tuo codice di plotting era già ottimo!)
        plt.figure(figsize=(14, 7)) 
        
        plt.bar(mesi, conteggi, color='skyblue', edgecolor='black', width=0.6)

        plt.xlabel('Mese', fontsize=12, fontweight='bold')
        plt.ylabel('Numero di Articoli', fontsize=12, fontweight='bold')
        plt.title('Distribuzione Articoli per Mese', fontsize=16)
        
        # Formattazione asse X
        plt.xticks(
            rotation=45, 
            ha='right', 
            fontsize=10 
        )
        
        plt.grid(axis='y', linestyle='--', alpha=0.5)

        # Etichette sopra le barre
        for i, v in enumerate(conteggi):
            plt.text(i, v + (max(conteggi)*0.01), str(v), ha='center', va='bottom', fontweight='bold')

        plt.subplots_adjust(bottom=0.2)
        plt.tight_layout()
        plt.show()

client.close()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_29108\3018232361.py:30: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['mese_anno'] = df['data'].dt.to_period('M')

# %%
# --- 1. PREPARAZIONE DATI BITCOIN (df_btc) ---
# Assicura che 'df_btc' sia caricato. Se non c'è, crea un placeholder.
if 'df' not in locals():
    print("ATTENZIONE: 'df_btc' non trovato. Caricalo prima (es. con yfinance).")
    df_btc = pd.DataFrame()
else:
    df_btc = df.copy() # Lavoriamo su una copia

# Assicuriamo che l'indice sia datetime
if not df_btc.empty:
    if not pd.api.types.is_datetime64_any_dtype(df_btc.index):
        df_btc.index = pd.to_datetime(df_btc.index)
    # Filtriamo dal 2021 in poi per coerenza
    df_btc_filtered = df_btc[df_btc.index >= '2021-01-01']
else:
    df_btc_filtered = pd.DataFrame()


# --- 2. RECUPERO DATI ARTICOLI (IL TUO CODICE FUNZIONANTE) ---
client = MongoClient("mongodb://localhost:27017")
db = client['bitcoin_project']
collection = db['Article']

projection = {"pub_date": 1, "_id": 0}
data = list(collection.find({}, projection))

if not data:
    print("Nessun dato trovato su MongoDB!")
else:
    # Creazione DataFrame
    df_articles = pd.DataFrame(data)
    
    if 'pub_date' in df_articles.columns:
        # Conversione e Pulizia
        df_articles['data'] = pd.to_datetime(df_articles['pub_date'], errors='coerce')
        df_articles = df_articles.dropna(subset=['data'])
        
        # Filtro temporale (opzionale, per allineare al grafico BTC)
        df_articles = df_articles[df_articles['data'] >= '2021-01-01']

        # Raggruppamento per mese
        conteggio_mensile = df_articles['data'].dt.to_period('M').value_counts().sort_index()

        # *** TRUCCO IMPORTANTE ***
        # Convertiamo l'indice (Period) in Timestamp (inizio mese)
        # Questo permette a Matplotlib di sovrapporre correttamente la linea del Bitcoin
        date_articoli = conteggio_mensile.index.to_timestamp()
        conteggi = conteggio_mensile.values

        # --- 3. GENERAZIONE GRAFICO COMBINATO ---
        fig, ax1 = plt.subplots(figsize=(14, 8))

        # ASSE Y SINISTRO (BARRE - ARTICOLI)
        ax1.bar(date_articoli, conteggi, color='skyblue', edgecolor='black', width=20, alpha=0.7, label='N. Articoli')
        
        ax1.set_xlabel('Data', fontsize=12, fontweight='bold')
        ax1.set_ylabel('Volume Articoli', fontsize=12, fontweight='bold', color='blue')
        ax1.tick_params(axis='y', labelcolor='blue')
        ax1.grid(axis='y', linestyle='--', alpha=0.5)

        # ASSE Y DESTRO (LINEA - PREZZO BITCOIN)
        if not df_btc_filtered.empty:
            ax2 = ax1.twinx()
            color_line = '#FF8C00' # Arancione Bitcoin
            
            # Gestione sicura della colonna Close
            try:
                # Prova accesso standard o MultiIndex
                prezzo = df_btc_filtered['Close']['BTC-USD'] if 'BTC-USD' in df_btc_filtered['Close'] else df_btc_filtered['Close']
            except:
                prezzo = df_btc_filtered.iloc[:, 0] # Fallback brutale alla prima colonna
            
            ax2.plot(df_btc_filtered.index, prezzo, color=color_line, linewidth=2.5, label='Prezzo BTC')
            ax2.set_ylabel('Prezzo Bitcoin (USD)', fontsize=12, fontweight='bold', color=color_line)
            ax2.tick_params(axis='y', labelcolor=color_line)

            # Legenda Unificata
            lines_1, labels_1 = ax1.get_legend_handles_labels()
            lines_2, labels_2 = ax2.get_legend_handles_labels()
            ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='upper left')
        else:
            ax1.legend(loc='upper left')

        plt.title('Confronto: Volume Notizie vs Prezzo Bitcoin', fontsize=16)
        fig.autofmt_xdate() # Formatta date asse X
        plt.tight_layout()
        plt.show()

    else:
        print("Errore: colonna 'pub_date' non trovata nel DataFrame.")

client.close()
# Out:
# C:\Users\tomma\AppData\Local\Temp\ipykernel_28212\1577494681.py:42: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   conteggio_mensile = df_articles['data'].dt.to_period('M').value_counts().sort_index()

# %% [markdown]
# ### Other news API:

# %%
key = os.getenv("NEWS_KEY")
url = ('https://newsapi.org/v2/everything?'
       'q=Bitcoin&'
       'from=2025-11-10&'
       'sortBy=popularity&'
       f'apiKey={key}')

# %%
news_resp = requests.get(url).json()
news_resp
# Out:
# {'status': 'ok',
#  'totalResults': 14234,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Joel Khalili',
#    'title': 'Inside a Wild Bitcoin Heist: Five-Star Hotels, Cash-Stuffed Envelopes, and Vanishing Funds',
#    'description': 'Sophisticated crypto scams are on the rise. But few of them go to the lengths one bitcoin mining executive experienced earlier this year.',
#    'url': 'https://www.wired.com/story/bitcoin-scam-mining-as-service/',
#    'urlToImage': 'https://media.wired.com/photos/6913b909f757bec53ccf7811/191:100/w_1280,c_limit/Bitcoin-Heist-Business-1304706668.jpg',
#    'publishedAt': '2025-11-17T10:00:00Z',
#    'content': 'As Kent Halliburton stood in a bathroom at the Rosewood Hotel in central Amsterdam, thousands of miles from home, running his fingers through an envelope filled with 10,000 in crisp banknotes, he sta… [+2362 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Nilay Patel',
#    'title': 'Square’s product chief on the death of the penny and the future of money',
#    'description': 'Today, I’m talking with Willem Avé, who’s head of product at Square. You know Square — it was started by billionaire Jack Dorsey, of Twitter fame, more than 15 years ago, and it got big on the back of that little magnetic reader that plugged into the headphon…',
#    'url': 'https://www.theverge.com/podcast/839062/square-product-chief-willem-ave-block-jack-dorsey-ai-bitcoin-crypto',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/12/DCD_1208.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-12-08T14:59:08Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nSquares Willem Avé on AI automation, investing in crypto, and what its like working for Jack Dorsey.\r\nby\r\nNilay PatelClose\r\nNilay Patel\r\nPosts from this author w… [+68989 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Elizabeth Lopatto',
#    'title': 'I looked into CoreWeave and the abyss gazed back',
#    'description': "Hello, my friends. Have you been feeling too sane lately? Have I got something for you! It is a company called CoreWeave. You may not have heard of it because it's not doing the consumer-facing part of AI. It's a data center company, the kind people talk abou…",
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/822011/coreweave-debt-data-center-ai',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/11/258082_BUBBLE-_coreweave_CVirginia23.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-11-17T14:49:46Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nMeet the company Nvidia is propping up.\r\nby\r\nElizabeth LopattoClose\r\nElizabeth Lopatto\r\nPosts from this author will be added to your daily email digest and your … [+44607 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'Bitcoin Continues Steep Decline, Down 34% Since Early October',
#    'description': 'The crypto bros are tired of winning.',
#    'url': 'https://gizmodo.com/bitcoin-continues-steep-decline-down-34-since-early-october-2000689539',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2023/11/f49a044d19bd3b833ac04154d28540ee.jpg',
#    'publishedAt': '2025-11-21T17:10:40Z',
#    'content': 'Bitcoin’s price just keeps falling. And nobody seems to know where the bottom might be this time.\r\nBitcoin dipped to a low of $80,760 on Friday before recovering above $85,000, only to dip again. The… [+3004 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Torpey',
#    'title': 'Europol Shuts Down Bitcoin Mixer That Processed €1.3 Billion Worth of Crypto',
#    'description': 'Centralized mixing tools for obscuring crypto transactions are the latest target of authorities.',
#    'url': 'https://gizmodo.com/europol-shuts-down-bitcoin-mixer-that-processed-e1-3-billion-worth-of-crypto-2000694020',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/12/crypto_mixer-1200x675.jpg',
#    'publishedAt': '2025-12-01T18:35:39Z',
#    'content': 'European law enforcement struck a blow against those seeking increased privacy for their bitcoin, dismantling the CryptoMixer service in a coordinated operation that netted over 25 million in seized … [+4623 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Torpey',
#    'title': 'Crypto’s Most Trusted Stablecoin Given Lowest Possible ‘Weak’ Rating By Major TradFi Agency',
#    'description': 'Trust the dusty old rating agency with the spotty history, or trust the brash young crypto company?',
#    'url': 'https://gizmodo.com/tether-usdt-sandp-downgrade-2000693464',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/tether-1200x675.jpg',
#    'publishedAt': '2025-11-30T18:07:41Z',
#    'content': 'Tether’s USDT, the dominant dollar-pegged stablecoin with nearly $185 billion in circulation, just took a hit from traditional finance rating powerhouse S&amp;P Global, as it downgraded its assessmen… [+4293 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Torpey',
#    'title': 'Homeland Security Is Reportedly Probing Bitcoin Mining Giant Bitmain for National Security Reasons',
#    'description': "And there's an additional Trump family connection.",
#    'url': 'https://gizmodo.com/homeland-security-is-reportedly-probing-bitcoin-mining-giant-bitmain-for-national-security-reasons-2000689746',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/10/sec-bitcoin-hack-arrest.jpg',
#    'publishedAt': '2025-11-23T10:00:14Z',
#    'content': 'According to a new report from Bloomberg, federal authorities have quietly been digging into Bitmain, the Beijing-based bitcoin mining hardware manufacturing giant, over fears that its devices could … [+5367 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Torpey',
#    'title': '$11 Million Crypto Theft in Broad Daylight Is Latest in Increasingly Common $5 Wrench Attacks',
#    'description': "It's cheaper than ever to turn antisocial behavior into big bucks.",
#    'url': 'https://gizmodo.com/11-million-crypto-theft-in-broad-daylight-is-latest-in-increasingly-common-5-wrench-attacks-2000691574',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/09/An-image-of-Bitcoin-cryptocurrency.jpg',
#    'publishedAt': '2025-11-25T21:30:11Z',
#    'content': 'In the quiet hum of a San Francisco morning, a routine knock at the door quickly turned into a nightmare of coercion and irreversible loss, as a man posing as a harmless delivery driver gained entry … [+5415 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Torpey',
#    'title': 'U.S. Bank Calls Ability to Freeze Stablecoins ‘Appealing’ as Crypto Has Completely Lost the Plot',
#    'description': 'Dark days for the bros.',
#    'url': 'https://gizmodo.com/u-s-bank-calls-ability-to-freeze-stablecoins-appealing-as-crypto-has-completely-lost-the-plot-2000692407',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/crypto_hack-1200x675.jpg',
#    'publishedAt': '2025-11-26T20:10:52Z',
#    'content': 'U.S. Bancorp, which does business as (and is better known as) U.S. Bank, has begun testing its own stablecoin on the Stellar blockchain. The pilot, detailed in a recent Bloomberg report, focuses on u… [+3764 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Rhett Jones',
#    'title': 'Trump Organization Announces Tokenized Hotel Development as Crypto ‘Crime Season’ Continues',
#    'description': "There's a big crypto pot just waiting for anyone to put money into it.",
#    'url': 'https://gizmodo.com/trump-organization-announces-tokenized-hotel-development-as-crypto-crime-season-continues-2000687133',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/Trump_saudi_MBS-1200x675.jpg',
#    'publishedAt': '2025-11-17T21:50:10Z',
#    'content': 'The Trump Organization and London-based luxury real estate developer DAR Global have announced a new hotel development known as Trump International Hotel Maldives, which will apparently be tokenized … [+5844 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Torpey',
#    'title': 'Crypto Founder Defends FBI Involvement After Developer Accidentally Causes Blockchain Split',
#    'description': 'Innocent pen testing mistake or premeditated attack?',
#    'url': 'https://gizmodo.com/crypto-founder-defends-fbi-involvement-after-developer-accidentally-causes-blockchain-split-2000690899',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/crypto_money-1200x675.jpg',
#    'publishedAt': '2025-11-25T14:10:46Z',
#    'content': 'On Friday, Cardano’s mainnet experienced a significant chain split after a single malformed delegation transaction exploited a vulnerability in the network’s node software. The issue stemmed from a d… [+7175 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Mike Pearl',
#    'title': 'Insider Trading Suspicions and Shafted Token Holders at the Heart of Latest Coinbase Controversy',
#    'description': 'A move that should have simplified trading is fraught with drama.',
#    'url': 'https://gizmodo.com/insider-trading-suspicions-and-shafted-token-holders-at-the-heart-of-latest-coinbase-controversy-2000690462',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2023/05/431a1adc20dab63ba03801e76ce9f312.jpg',
#    'publishedAt': '2025-11-24T11:05:14Z',
#    'content': 'Coinbase is betting big on fixing one of crypto’s oldest headaches: the initial coin offerings (ICOs) that fueled the 2017 boom and left a trail of rug pulls in their wake. However, the exchanges lat… [+4713 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'jciolli@businessinsider.com (Joe Ciolli)',
#    'title': '4 reasons why bitcoin is slogging through an epic plunge',
#    'description': 'There are a few reasons why this sell-off in bitcoin feels different than ones past.',
#    'url': 'https://www.businessinsider.com/bitcoin-price-crash-explained-headwinds-hurting-crypto-market-outlook-2025-12',
#    'urlToImage': 'https://i.insider.com/692e03407ecd1d1da662b675?width=1024&format=jpeg',
#    'publishedAt': '2025-12-02T10:25:39Z',
#    'content': "November wasn't kind to some of the market's high-flying risk-on investments.\r\nThe Nasdaq 100 dominated by the tech elite driving the AI trade posted its first monthly decline since March.\r\nBitcoin, … [+3212 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'jsor@businessinsider.com (Jennifer Sor)',
#    'title': "Why Japan's central bank is stirring up fresh jitters across markets",
#    'description': 'Investors were fretting about interest rates in Japan on Monday. Fears about the "yen carry trade" have sparked bouts of volatility in markets before.',
#    'url': 'https://www.businessinsider.com/yen-carry-trade-boj-japan-interest-rate-hike-stocks-bonds-2025-12',
#    'urlToImage': 'https://i.insider.com/692dd372abd5e944effbcfa9?width=1200&format=jpeg',
#    'publishedAt': '2025-12-01T18:15:12Z',
#    'content': "The Bank of Japan raised fears about a repeat of the yen carry trade unwind to start the week, reviving concerns about the country's central bank tightening monetary policy. \r\nSo why exactly is a cen… [+3082 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "Bitcoin Erases Year's Gain as Crypto Bear Market Deepens",
#    'description': '655"Just a little more than a month after reaching an all-time high, Bitcoin has erased the more than 30% gain registered since the start of the year..." reports Bloomberg:\n\nThe dominant cryptocurrency fell below US$93,714 on Sunday, pushing the price beneath…',
#    'url': 'https://news.slashdot.org/story/25/11/17/024220/bitcoin-erases-years-gain-as-crypto-bear-market-deepens',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2025-11-17T08:35:00Z',
#    'content': 'The dominant cryptocurrency fell below US$93,714 on Sunday, pushing the price beneath the closing level reached at the end of last year, when financial markets were rallying following President Donal… [+2188 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Harvard Has Almost Half a Billion Dollars in Crypto',
#    'description': "An anonymous reader shares a report: Harvard is ramping up its holdings in cryptocurrency. The nation's oldest university reported a $443 million investment in BlackRock's iShares Bitcoin Trust in the third quarter. The school now holds 6.8 million shares of …",
#    'url': 'https://slashdot.org/story/25/11/17/1834233/harvard-has-almost-half-a-billion-dollars-in-crypto',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2025-11-17T20:41:00Z',
#    'content': "Harvard is ramping up its holdings in cryptocurrency. The nation's oldest university reported a $443 million investment in BlackRock's iShares Bitcoin Trust in the third quarter. The school now holds… [+425 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'BeauHD',
#    'title': 'Swiss Illegal Cryptocurrency Mixing Service Shut Down',
#    'description': 'Longtime Slashdot reader krouic shares a report from Europol: From November 24-28, 2025, Europol supported an action week conducted by law enforcement authorities from Switzerland and Germany in Zurich, Switzerland. The operation focused on taking down the il…',
#    'url': 'https://slashdot.org/story/25/12/02/0042253/swiss-illegal-cryptocurrency-mixing-service-shut-down',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2025-12-02T01:25:00Z',
#    'content': 'The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way.'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Katherine Li',
#    'title': "Meet Jay Graber, the CEO of Bluesky, who is building a 'billionaire-proof' and decentralized social media platform",
#    'description': 'Graber spent her early years studying how technology interacts with society, and now leads Bluesky that is looking to be "billionaire-proof."',
#    'url': 'https://www.businessinsider.com/meet-jay-graber-ceo-bluesky-who-wants-change-social-media',
#    'urlToImage': 'https://i.insider.com/68f19a0d1c1f80efbec5c236?width=1200&format=jpeg',
#    'publishedAt': '2025-11-30T12:51:02Z',
#    'content': 'Jay Graber is the CEO of Bluesky, a decentralized social media platform with over 40 million registered users.Samantha Burkardt/SXSW Conference & Festivals via Getty Images\r\n<ul><li>Jay Graber studie… [+10460 chars]'},
#   {'source': {'id': None, 'name': 'Kotaku'},
#    'author': 'Claire Jackson',
#    'title': 'GameStop Will Let You Turn In A Deer Head For GTA 6 Discounts In ‘Trade Anything’ Stunt',
#    'description': 'Even if you’re not planning to trade something in, it might be worth hanging around your local GameStop for the theater of it all\nThe post GameStop Will Let You Turn In A Deer Head For GTA 6 Discounts In ‘Trade Anything’ Stunt appeared first on Kotaku.',
#    'url': 'https://kotaku.com/gamestop-trade-anything-taxidermy-store-credit-2000644850',
#    'urlToImage': 'https://kotaku.com/app/uploads/2025/11/gamestop-1200x675.jpg',
#    'publishedAt': '2025-11-17T16:23:22Z',
#    'content': 'Soon youll be able to walk into a GameStop to trade in, well, nearly anything. For one day only in December the company will accept almost any piece of junk you try to give it.\r\nRead More:GameStop Au… [+2937 chars]'},
#   {'source': {'id': None, 'name': 'Hipertextual'},
#    'author': 'Rubén Chicharro',
#    'title': 'No eres el único que le ha preguntado esto a Alexa: estas son las peticiones más realizadas de 2025',
#    'description': 'Alexa, el asistente inteligente disponible en los Amazon Echo y otros altavoces inteligentes, es uno de los más usados en países como España. Los usuarios no paran de realizar preguntas relacionadas con la actualidad, el clima, acontecimientos importantes, mú…',
#    'url': 'https://hipertextual.com/tecnologia/no-eres-el-unico-que-le-ha-preguntado-esto-a-alexa-estas-son-las-peticiones-mas-realizadas-de-2025/',
#    'urlToImage': 'https://i0.wp.com/imgs.hipertextual.com/wp-content/uploads/2025/11/amazon-echo-dot-max-005.jpg?fit=1920%2C1282&quality=70&strip=all&ssl=1',
#    'publishedAt': '2025-12-04T10:30:00Z',
#    'content': 'Alexa, el asistente inteligente disponible en los Amazon Echo y otros altavoces inteligentes, es uno de los más usados en países como España. Los usuarios no paran de realizar preguntas relacionadas … [+3436 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Ramzan Karmali',
#    'title': 'Why has Bitcoin erased all its 2025 gains?',
#    'description': 'Bitcoin fell into the red for 2025. After topping $126,000 in October, Bitcoin has fallen sharply, wiping out its 2025 gains. Bitcoin’s total market value...',
#    'url': 'https://finance.yahoo.com/video/why-bitcoin-erased-2025-gains-113920868.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Kd07Ndbja.lvLCnRCx.QKg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2025-11/c0816ba0-c3a6-11f0-bd67-f2bf37ec7835',
#    'publishedAt': '2025-11-17T11:39:20Z',
#    'content': "Bitcoin fell into the red for 2025. In fact, around $600 billion has been wiped off its market value after it reached its record high back in October. \r\nBut what's going on? 2025 was meant to be the … [+869 chars]"},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'Pooja Rajkumari',
#    'title': 'Analyst warns Bitcoin could drop to $10K, as price crashes to $86K',
#    'description': 'Bitcoin extended its November slump on Nov. 20, briefly dipping below $88,000. According to CoinGecko data, Bitcoin traded around $87,319 intraday, down...',
#    'url': 'https://www.thestreet.com/crypto/trading/analyst-warns-bitcoin-could-drop-to-10k',
#    'urlToImage': 'https://media.zenfs.com/en/thestreet_881/7f2f2f6f1b5e3914e4795503f733a004',
#    'publishedAt': '2025-11-20T20:11:47Z',
#    'content': 'Bitcoin extended its November slump on Nov. 20, briefly dipping below $88,000.\r\nAccording to CoinGecko data, Bitcoin traded around $87,319 intraday, down about 4% over the past 24 hours and nearly 13… [+1242 chars]'},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'Pooja Rajkumari',
#    'title': 'Trump-backed stock halts multiple times after wild 51% crash in 30 minutes',
#    'description': 'American Bitcoin Corp. (NASDAQ: ABTC), a Bitcoin (BTC) mining firm co-founded by Eric Trump, saw its shares crash more than 50% in less than 30 minutes on...',
#    'url': 'https://www.thestreet.com/crypto/trading/trump-backed-stock-halts-multiple-times-after-wild-51-crash-in-30-minutes',
#    'urlToImage': 'https://media.zenfs.com/en/thestreet_881/2ba89e1cdd2bb8bbb69a8abe1130da5e',
#    'publishedAt': '2025-12-02T21:13:59Z',
#    'content': 'American Bitcoin Corp. (NASDAQ: ABTC), a Bitcoin (BTC) mining firm co-founded by Eric Trump, saw its shares crash more than 50% in less than 30 minutes on Dec. 2, prompting multiple trading halts.\r\nA… [+1316 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': "Michael Saylor's MicroStrategy moves billions in Bitcoin",
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_ac657588-7d22-431c-b323-c39e3e464a37',
#    'urlToImage': None,
#    'publishedAt': '2025-11-28T22:00:50Z',
#    'content': "If you click 'Accept all', we and our partners, including 240 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+714 chars]"},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'Anand Sinha',
#    'title': 'Smartest man alive reveals new Bitcoin target',
#    'description': 'YoungHoon Kim, who claims to hold the world record for highest IQ of 276, has revealed the next Bitcoin (BTC) price target. Kim earlier predicted in...',
#    'url': 'https://www.thestreet.com/crypto/investing/smartest-man-alive-new-bitcoin-price',
#    'urlToImage': 'https://media.zenfs.com/en/thestreet_881/f9fa2849b9cfc41d63f7b2142c0ae1ca',
#    'publishedAt': '2025-11-17T18:05:55Z',
#    'content': 'YoungHoon Kim, who claims to hold the world record for highest IQ of 276, has revealed the next Bitcoin (BTC) price target.\r\nKim earlier predicted in September that Bitcoin\xa0will grow at least 100 tim… [+1905 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': None,
#    'title': 'Why bitcoin, crypto are crashing now',
#    'description': None,
#    'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_18000f1a-b2f1-47fb-8cfe-21c77a2b6167',
#    'urlToImage': None,
#    'publishedAt': '2025-12-01T13:01:43Z',
#    'content': "If you click 'Accept all', we and our partners, including 240 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+714 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Yahoo Finance Video',
#    'title': 'Two catalysts bitcoin investors should watch',
#    'description': "Bitcoin (BTC-USD) has seen its price fall sharply over the last two weeks. Grayscale managing director of research Zach Pandl shares two catalysts that he's ...",
#    'url': 'https://finance.yahoo.com/video/two-catalysts-bitcoin-investors-watch-210035172.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/5hzGTa1Lf7JNnvoPPmKePA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzQ-/https://s.yimg.com/os/creatr-uploaded-images/2025-11/3052b720-c700-11f0-bedb-fd26c06fdbcb',
#    'publishedAt': '2025-11-21T21:00:35Z',
#    'content': "Zach, what's going to turn things around here? You know, I guess one of two things can happen. Either the selling exhausts itself or something positive happens that actually makes people want to come… [+1214 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Ines Ferré',
#    'title': 'Bitcoin rises above $90,000 as cryptocurrency attempts recovery amid stock market gains',
#    'description': 'Bitcoin has struggled to bounce back meaningfully despite a price uptick on Wednesday.',
#    'url': 'https://finance.yahoo.com/news/bitcoin-rises-above-90000-as-cryptocurrency-attempts-recovery-amid-stock-market-gains-193405385.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/.Z5tyxKY78q5nSzRFNKQXQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03NjQ-/https://s.yimg.com/os/creatr-uploaded-images/2021-04/5af69a20-a8e5-11eb-bf7f-5f2e9fe992ce',
#    'publishedAt': '2025-11-26T19:34:05Z',
#    'content': "Bitcoin (BTC-USD) rose above $90,000 on Wednesday, but some strategists warned the price action isn't necessarily a sign of a meaningful V-shaped recovery despite a risk-on mood in the stock market.\r… [+3504 chars]"},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Oihyun Kim',
#    'title': 'Why Does Asia Keep Buying Bitcoin While Americans Are Selling?',
#    'description': 'Asian buyers absorb Bitcoin dips while US sessions drive losses, reflecting key regional divergence.',
#    'url': 'https://beincrypto.com/bitcoin-divergence-asia-us-market-split/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/GzybvIUWaNtn.z96eTn6Ug--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/beincrypto_us_662/713b9f283f1a0a64377c261edb8c74f9',
#    'publishedAt': '2025-11-21T00:19:25Z',
#    'content': "MicroStrategy Bitcoin premium. Photo by BeInCrypto\r\nBitcoin's recent price decline has revealed a sharp split in trading, with US sessions driving sell-offs while Asian traders steadily buy the dip. … [+4116 chars]"},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Oihyun Kim',
#    'title': 'Bitcoin Touches $93K Low as Market Sentiment Hits Extreme Fear',
#    'description': 'Bitcoin rebounds after $93K low, as $510M liquidations and extreme fear grip the market.',
#    'url': 'https://beincrypto.com/bitcoin-rebounds-extreme-fear-liquidations/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/qmZQ9gr.JRuMGC_oZ_wlPQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/beincrypto_us_662/0b3df591e4a20e4570628b30a5734577',
#    'publishedAt': '2025-11-16T23:42:37Z',
#    'content': 'Altcoins November fear. Photo by BeInCrypto\r\nBitcoin briefly dropped to $93,000 early Monday in Asia before rebounding, sparking $510 million in 24-hour liquidations and wiping out all year-to-date g… [+2477 chars]'},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Lockridge Okoth',
#    'title': 'Satoshi Nakamoto Loses $43 Billion as Bitcoin Price Falls Over 30%',
#    'description': 'Satoshi Nakamoto loses over $40 billion as Bitcoin drops 30%, raising questions about dormant early coins.',
#    'url': 'https://beincrypto.com/satoshi-nakamoto-bitcoin-fortune-drop/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/mR4XeRbpABaV_RqvD0AEVA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/beincrypto_us_662/511288d6370af6ecb96d6a4347d86ef3',
#    'publishedAt': '2025-11-23T21:40:50Z',
#    'content': "Bitcoin Satoshi. Photo by BeInCrypto\r\nSatoshi Nakamoto's legendary Bitcoin fortune has dropped by an estimated $41 billion, as BTCs price slid more than 30% from its all-time high.\r\nThe pseudonymous … [+3331 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bibhu Pattnaik',
#    'title': 'JPMorgan Forecasts Bitcoin Bottom, Anticipates $28.3 Trillion Challenge To Gold By 2026',
#    'description': 'Analysts at JPMorgan have pinpointed the lowest point of the ongoing Bitcoin (CRYPTO: BTC) price fall and also projected a substantial challenge to gold’s...',
#    'url': 'https://finance.yahoo.com/news/jpmorgan-forecasts-bitcoin-bottom-anticipates-183113549.html',
#    'urlToImage': 'https://media.zenfs.com/en/Benzinga/d948b3623c38158fbc0388cafcb23744',
#    'publishedAt': '2025-11-16T18:31:13Z',
#    'content': 'Analysts at\xa0JPMorgan\xa0have pinpointed the lowest point of the ongoing Bitcoin(CRYPTO: BTC) price fall and also projected a substantial challenge to golds market capitalization by 2026.\r\nWhat Happened:… [+2398 chars]'},
#   {'source': {'id': None, 'name': 'Coingape'},
#    'author': 'Varinder Singh',
#    'title': 'Legendary Trader Peter Brandt Warns Deeper Bitcoin Price Crash Below $58K',
#    'description': 'Legendary trader Peter Brandt issues another bearish Bitcoin price prediction on Monday, warning about a major upcoming BTC crash. Global crypto market cap...',
#    'url': 'https://coingape.com/legendary-trader-peter-brandt-warns-deeper-bitcoin-price-crash-below-58k/',
#    'urlToImage': 'https://media.zenfs.com/en/coingape_360/9666ffd53aebba899efea6ee3770e282',
#    'publishedAt': '2025-12-01T10:12:20Z',
#    'content': 'Legendary Trader Peter Brandt Warns Deeper Bitcoin Price Crash Below $58K Source: CoinGape\r\n<ul><li>Veteran trader Peter Brandt warns about Bitcoin price crash to $70k and mid-$40k.\r\n</li><li>Brandt … [+2359 chars]'},
#   {'source': {'id': None, 'name': 'Dlnews.com'},
#    'author': 'Pedro Solimano',
#    'title': 'Trouble mounts for Bitcoin treasuries as unrealised losses near $1 billion',
#    'description': 'Metaplanet has gone from $600 million in unrealised profits to $530 million in losses. Strategy has shrunk from a 79% premium to trading at a 15.5% discount ...',
#    'url': 'https://www.dlnews.com/articles/markets/bitcoin-treasuries-have-nearly-1billion-in-unrealised-losses/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/lGAt8a0eiB5YdPjnYl5_Tw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03ODU-/https://media.zenfs.com/en/dlnews_702/f7705e79d546e74a3703bc4455cdf518',
#    'publishedAt': '2025-12-05T21:06:29Z',
#    'content': 'Bitcoin treasury companies are bleeding as Bitcoins price flutters around $89,000.\r\nMetaplanet, one of the largest Bitcoin treasury companies after Strategy, has swung from over $600 million in unrea… [+2990 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Ines Ferré',
#    'title': "Bitcoin price under pressure, slips below $92,000 as 'self-fulfilling prophecy' puts 4-year cycle in focus",
#    'description': 'Bitcoin prices were below $92,000 on Monday, while questions mount about whether the market has already hit its cycle high.',
#    'url': 'https://finance.yahoo.com/news/bitcoin-price-under-pressure-slips-below-92000-as-self-fulfilling-prophecy-puts-4-year-cycle-in-focus-203113535.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/AO5RBYMomqyFL4Z2L01Xmw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD0xMDcx/https://s.yimg.com/os/creatr-uploaded-images/2022-06/1701f760-eb3d-11ec-9fcd-fda7580ab069',
#    'publishedAt': '2025-11-17T20:31:13Z',
#    'content': 'Bitcoin (BTC-USD) remained under pressure on Monday, falling below $92,000 and bringing its losses from record highs in October to more than 26%. The drop is prompting questions about whether this re… [+2621 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Ines Ferré',
#    'title': "Bitcoin price under pressure, slips below $93,000 as 'self-fulfilling prophecy' puts 4-year cycle in focus",
#    'description': 'Bitcoin prices were below $93,000 on Monday, while questions mount about whether the market has already hit its cycle high.',
#    'url': 'https://finance.yahoo.com/news/bitcoin-price-under-pressure-slips-below-93000-as-self-fulfilling-prophecy-puts-4-year-cycle-in-focus-184650240.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/AO5RBYMomqyFL4Z2L01Xmw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD0xMDcx/https://s.yimg.com/os/creatr-uploaded-images/2022-06/1701f760-eb3d-11ec-9fcd-fda7580ab069',
#    'publishedAt': '2025-11-17T18:46:50Z',
#    'content': 'Bitcoin (BTC-USD) remained under pressure on Monday, falling below $93,000 and bringing its losses from record highs in October to around 25%. The drop is prompting questions about whether this remai… [+2618 chars]'},
#   {'source': {'id': None, 'name': 'Cryptonews'},
#    'author': 'Anas Hassan',
#    'title': 'Coinbase Warns Bitcoin Under Pressure, Citing ETF Outflows and Whales Exit',
#    'description': 'Coinbase Institutional has issued a stark warning to investors as Bitcoin breaks through critical support levels, citing multiple bearish indicators...',
#    'url': 'https://cryptonews.com/news/coinbase-warns-bitcoin-under-pressure-citing-etf-outflows-and-whales-exit/',
#    'urlToImage': 'https://media.zenfs.com/en/cryptonews_us_711/de9973b6e6855f3efeeb96e4e264ac55',
#    'publishedAt': '2025-12-03T15:07:03Z',
#    'content': 'Coinbase Institutional has issued a stark warning to investors as Bitcoin breaks through critical support levels, citing multiple bearish indicators, including massive ETF outflows, whale distributio… [+4961 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Ines Ferré',
#    'title': "Bitcoin price under pressure drops below $92,000 as 'self-fulfilling prophecy' puts 4-year cycle in focus",
#    'description': 'Bitcoin prices were below $92,000 on Monday, while questions mount about whether the market has already hit its cycle high.',
#    'url': 'https://finance.yahoo.com/news/bitcoin-price-under-pressure-drops-below-92000-as-self-fulfilling-prophecy-puts-4-year-cycle-in-focus-203113055.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/AO5RBYMomqyFL4Z2L01Xmw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD0xMDcx/https://s.yimg.com/os/creatr-uploaded-images/2022-06/1701f760-eb3d-11ec-9fcd-fda7580ab069',
#    'publishedAt': '2025-11-17T20:31:13Z',
#    'content': 'Bitcoin (BTC-USD) remained under pressure on Monday, falling below $92,000 and bringing its losses from record highs in October to more than 26%. The drop is prompting questions about whether this re… [+2621 chars]'},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Dominik Juraszek',
#    'title': 'Polish Crypto Analyst Apologizes After Bitcoin ‘Santa Rally’ Forecast Fails',
#    'description': 'Polish crypto analyst Robert “El Profesor” Ruszała publicly apologizes after his Bitcoin forecast collapses, detailing what went wrong.',
#    'url': 'https://beincrypto.com/bitcoin-plan-failed-polish-analyst-apologizes/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/go9zfAymGH6WQYW5W6KF.w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/beincrypto_us_662/30a62fe9b9759bf3f95d7b7a8ecb2b4b',
#    'publishedAt': '2025-11-24T00:56:57Z',
#    'content': 'Epstein Files Bitcoin. Photo by BeInCrypto\r\nA well-known Polish market analyst has publicly apologized after his latest Bitcoin outlook collapsed within weeks, sparking debate across social media.\r\nR… [+2016 chars]'},
#   {'source': {'id': None, 'name': 'Investopedia'},
#    'author': 'Crystal Kim',
#    'title': "Strategy's Michael Saylor Has a Message for Bitcoin Investors as Its Price Falls",
#    'description': "The world's largest cryptocurrency has erased almost all of its 2025 gains and is now lagging the broad stock market.",
#    'url': 'https://www.investopedia.com/strategy-s-michael-saylor-has-a-message-for-bitcoin-investors-as-its-price-falls-11849689',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/vxO6ioydNQ_0MBKecXajjg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MTE-/https://media.zenfs.com/en/investopedia_245/1828f525da53775c7c19e3adddf8bc0d',
#    'publishedAt': '2025-11-14T19:18:55Z',
#    'content': "Peter Dazeley / Getty Images\r\n Bitcoin's price is at some of its lowest levels in months.\r\n<ul><li>Crypto followers turned to bitcoin evangelist and Strategy founder Michael Saylor for a sign as the … [+3318 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Yahoo Finance Video',
#    'title': 'Bitcoin bounces higher: Why it may (or may not) continue to rise',
#    'description': "Bitcoin (BTC-USD) is rising slightly on Monday, though it's still down about 20% over the past month. Yahoo Finance Senior Reporter Ines Ferré breaks down...",
#    'url': 'https://finance.yahoo.com/video/bitcoin-bounces-higher-why-may-202023255.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/ItUsyGXTe_P3RtFHi1zIMw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2025-11/81e8ae90-c972-11f0-94ff-ff05ae89244b',
#    'publishedAt': '2025-11-24T20:20:23Z',
#    'content': 'Well Bitcoin on a bit of a turnaround here. The cryptocurrency moving higher after dropping more than 30% from its peak. Bitcoin ETFs on track for their worst monthly outflow as investors pulling out… [+2101 chars]'},
#   {'source': {'id': None, 'name': 'BeInCrypto'},
#    'author': 'Oluwapelumi Adejumo',
#    'title': 'Bitcoin Miner Reserves Plunge to Record Low as Revenue Collapses',
#    'description': 'Bitcoin miners have offloaded more than 30,000 BTC in 48 hours, pushing reserves to a record low as their revenues collapse.',
#    'url': 'https://beincrypto.com/bitcoin-miner-revenues-hit-historic-lows/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/x6LSWT7wYBbVd9SMCV8.pw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/beincrypto_us_662/aac0db2e79dfec45dde4c263e448b756',
#    'publishedAt': '2025-11-23T12:30:00Z',
#    'content': 'Bitcoin mining. Photo by BeInCrypto\r\nBitcoin miners are aggressively draining their reserves in a bid to shore up balance sheets against a historic collapse in revenue efficiency.\r\nData from CryptoQu… [+2204 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Carlos Garcia',
#    'title': 'Harvard now owns nearly half a billion dollars worth of Bitcoin, filings show',
#    'description': 'The Ivy League school invested more than 20% of its U.S.-listed public equity holdings in a crypto ETF.',
#    'url': 'https://finance.yahoo.com/news/harvard-now-owns-nearly-half-202559941.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/oWzalGfhdOM6zRhGsPhfsg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/fortune_175/b4a2f5c88b70df1808a453260945d29a',
#    'publishedAt': '2025-11-17T20:25:59Z',
#    'content': 'Harvard is home to top intellectuals, famous alumni, and, more recently, a sizable hoard of Bitcoin. The university has more than $442 million dollars in the BlackRock-issued ETF called iShares Bitco… [+1900 chars]'},
#   {'source': {'id': None, 'name': 'Investopedia'},
#    'author': 'Crystal Kim',
#    'title': "Bitcoin's Price May Be Falling, But Michael Saylor Feels 'Indestructible'",
#    'description': "The world's most well-known and biggest cryptocurrency is continuing to sink. On Wednesday, bitcoin set a new weekly low, briefly falling below $89,000...",
#    'url': 'https://www.investopedia.com/bitcoin-s-price-may-be-falling-but-michael-saylor-feels-indestructible-mstr-btc-11852845',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/WTpNBrB7MhhQKCgy.Hzsuw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/investopedia_245/b6d552766c186993b7de9e5ef5c35636',
#    'publishedAt': '2025-11-19T19:36:44Z',
#    'content': "Chris Kleponis / CNP / Bloomberg via Getty Images\r\n Strategy's impresario Michael Saylor remains a backerand buyerof bitcoin.\r\n<ul><li>The price of the world's largest cryptocurrency fell below its w… [+2416 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'David Okoya',
#    'title': "Grant Cardone Says There Will Be 'A Massive Implosion' Of Bitcoin Treasury Companies",
#    'description': 'Digital asset treasury companies may pose a threat to Bitcoin, according to real estate guru Grant Cardone. “I think there’s going to be a massive implosion ...',
#    'url': 'https://finance.yahoo.com/news/grant-cardone-says-massive-implosion-030122060.html',
#    'urlToImage': 'https://media.zenfs.com/en/benzinga_79/29b39318bbd3991d70c1ce916d4a9a54',
#    'publishedAt': '2025-11-10T03:01:22Z',
#    'content': 'Benzinga and Yahoo Finance LLC may earn commission or revenue on some items through the links below.\r\nDigital asset treasury companies may pose a threat to Bitcoin, according to real estate guru Gran… [+2997 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Yahoo Finance Video',
#    'title': "Grant Cardone's real estate-bitcoin hybrid might disrupt the REIT industry",
#    'description': 'Is a new real estate-bitcoin hybrid the key to building real wealth? Host Ross Mac speaks with Grant Cardone, CEO of Cardone Capital. Cardone breaks down his...',
#    'url': 'https://finance.yahoo.com/video/grant-cardones-real-estate-bitcoin-200051355.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/HWAqOc4zozNaCzo27ld0lA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2025-11/3725e170-c58f-11f0-bdd0-7ea65a347265',
#    'publishedAt': '2025-11-21T20:00:51Z',
#    'content': "like let's actually talk about how the hybrid works, right? I would imagine obviously, if there's a hybrid and there's a call it 50% draw down on the price of Bitcoin, what does that mean to the inve… [+2987 chars]"},
#   {'source': {'id': 'crypto-coins-news', 'name': 'Crypto Coins News'},
#    'author': 'Kurt Robson',
#    'title': 'Bitcoin Falls Below $98,000 — Will It Continue To Drop? We Asked ChatGPT',
#    'description': 'Bitcoin’s drop to $96,712 has intensified fears of a deeper holiday-season correction. We asked ChatGPT and Grok to explore the possibilities. CCN analyst...',
#    'url': 'https://www.ccn.com/news/crypto/bitcoin-falls-below-98000-will-it-continue-to-drop-we-asked-chatgpt/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/0_Yt6hnU9k5Z3FQi1bh5ww--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/ccn_928/f5107a604edfe7a20615b7c5c411781d',
#    'publishedAt': '2025-11-14T08:47:15Z',
#    'content': 'Could Bitcoin tumble any further down the mountain? | Source: Image created with Gemini\r\nKey Takeaways\r\n<ul><li>Bitcoins drop to $96,712 has intensified fears of a deeper holiday-season correction.\r\n… [+3222 chars]'},
#   {'source': {'id': None, 'name': 'Gadgetreview.com'},
#    'author': 'Annemarije de Boer',
#    'title': 'Bitcoin’s December Disaster: The 4 Horsemen of the Crypto Apocalypse Are Here',
#    'description': "Bitcoin crashes 32% in December breaking typical holiday patterns as MicroStrategy's potential forced selling could trigger another 30% decline to $60k.",
#    'url': 'https://www.gadgetreview.com/bitcoins-december-disaster-the-4-horsemen-of-the-crypto-apocalypse-are-here',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/tGHZDziBVDnLpyvTgOTFXA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD05MDA-/https://media.zenfs.com/en/gadget_review_articles_822/35b226044a6304eae14eb6751ea3538f',
#    'publishedAt': '2025-12-03T17:09:39Z',
#    'content': 'Image credit: Wikimedia\r\nForget everything you know about Bitcoins December performance. While the worlds largest cryptocurrency typically delivers holiday cheerfinishing positive roughly half the ti… [+2523 chars]'},
#   {'source': {'id': None, 'name': 'Cryptonews'},
#    'author': 'Anas Hassan',
#    'title': 'World’s Smartest Man Forecasts Bitcoin to Reach $220,000 in the Next 45 Days',
#    'description': 'YoungHoon Kim, widely promoted as the “world’s smartest man” with a claimed IQ of 276, has predicted that Bitcoin could hit $220,000 within the next 45...',
#    'url': 'https://cryptonews.com/news/worlds-smartest-man-forecasts-bitcoin-to-reach-220000-in-the-next-45-days/',
#    'urlToImage': 'https://media.zenfs.com/en/cryptonews_us_711/b91c836da575bf6a8ff330c4580b48c2',
#    'publishedAt': '2025-11-17T14:06:54Z',
#    'content': 'YoungHoon Kim, widely promoted as the “world’s smartest man” with a claimed IQ of 276, has predicted that Bitcoin could hit $220,000 within the next 45 days.\r\nHe made the bold call on November 16 in … [+3427 chars]'},
#   {'source': {'id': None, 'name': 'Geekspin.co'},
#    'author': 'Christian Saclao',
#    'title': 'World’s smartest man predicts Bitcoin will hit 220K in 45 days',
#    'description': 'A viral prediction is sending shockwaves through the crypto world: a man dubbed as the “world’s smartest,” claiming an IQ of 276, insists Bitcoin is on track...',
#    'url': 'https://geekspin.co/smartest-man-bitcoin-will-hit-220k/',
#    'urlToImage': 'https://media.zenfs.com/en/geekspin_390/4dd752ab795e13e9bf9dc9d3b9ca10f5',
#    'publishedAt': '2025-11-18T01:04:33Z',
#    'content': 'Can Bitcoin really hit $220K in 45 days? A bold prediction has sparked heated debates online. | ©Image Credit: Kanchanara/Unsplash\r\nA viral prediction is sending shockwaves through the crypto world: … [+2782 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bloomberg',
#    'title': "Trump's Crypto Hype Fades: Is Bitcoin in Trouble?",
#    'description': 'Just a little more than a month after hitting an all-time high, Bitcoin has wiped out over 30% of its gains for the year. The excitement around the Trump...',
#    'url': 'https://finance.yahoo.com/video/trumps-crypto-hype-fades-bitcoin-084239341.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/UneNytIndeHr0DlUoJzvYg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/bloomberg_markets_video_2/4b40dd0a306c17e33f296d1d120a48fa',
#    'publishedAt': '2025-11-17T08:42:39Z',
#    'content': "Just a little more than a month after hitting an all-time high, Bitcoin has wiped out over 30% of its gains for the year. The excitement around the Trump administration's pro-crypto stance is fading,… [+286 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bloomberg',
#    'title': 'Bitcoin Selloff Deepens, Falling to Seven Month Low',
#    'description': 'Bitcoin fell below $90,000, extending its decline from a record of more than $126,000 set in early October and deepening a slide that has erased the...',
#    'url': 'https://finance.yahoo.com/video/bitcoin-selloff-deepens-falling-seven-111134825.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/ir7qHoMfHYvYgvKTetGFVA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/bloomberg_markets_video_2/232a254544d609243f2e81fc82185683',
#    'publishedAt': '2025-11-18T11:11:34Z',
#    'content': "Bitcoin fell below $90,000, extending its decline from a record of more than $126,000 set in early October and deepening a slide that has erased the cryptocurrency's gains for 2025. Anna Irrera repor… [+26 chars]"},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'Pooja Rajkumari',
#    'title': 'Jim Cramer claims ‘a cabal’ is keeping Bitcoin above $90K',
#    'description': 'Bitcoin (BTC) has been struggling to recover from its slump in October. November is not going as expected, and more often we see the cryptocurrency swinging ...',
#    'url': 'https://www.thestreet.com/crypto/trading/jim-cramer-blames-cabal-for-keeping-bitcoin-below-90k',
#    'urlToImage': 'https://media.zenfs.com/en/thestreet_881/386b3432563189d74e0e21c73aea452a',
#    'publishedAt': '2025-11-19T17:23:02Z',
#    'content': 'Bitcoin (BTC) has been struggling to recover from its slump in October.\r\nNovember is not going as expected, and more often we see the cryptocurrency swinging near the $90,000 range.\r\nOn Nov. 18, Bitc… [+1899 chars]'},
#   {'source': {'id': None, 'name': 'CoinDesk'},
#    'author': 'CoinDesk',
#    'title': 'Bitcoin Whales Are Accumulating BTC at Multi-Month Lows',
#    'description': 'As Bitcoin\'s price plunges to multi-month lows, holding below $100,000, "smart money" is making a move. This "Chart of the Day" shows a sharp spike in...',
#    'url': 'https://videos.coindesk.com/previews/JF8HgXML',
#    'urlToImage': 'https://media.zenfs.com/en/coindesk_75/f5402be5f3493e619a9dcb1bc8eb8429',
#    'publishedAt': '2025-11-17T20:11:15Z',
#    'content': 'As Bitcoin\'s price plunges to multi-month lows, holding below $100,000, "smart money" is making a move. This "Chart of the Day" shows a sharp spike in Bitcoin whale accumulation, with the count of en… [+303 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Yahoo Finance Video',
#    'title': 'Bitcoin extends losses, on track for worst month since 2022',
#    'description': 'Bitcoin (BTC-USD) prices fell by more than 8% in the early morning on Friday. Yahoo Finance Markets & Data Editor Jared Blikre breaks down the trading action...',
#    'url': 'https://finance.yahoo.com/video/bitcoin-extends-declines-track-worst-142209709.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/PkvkPW6PFn6nxYhWvtlBjQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzI-/https://s.yimg.com/os/creatr-uploaded-images/2025-11/6082f150-c6e5-11f0-bfdb-0deca1999860',
#    'publishedAt': '2025-11-21T14:22:09Z',
#    'content': "You got Bitcoin, the selling selling accelerating this morning. It did bounce a little bit off the lows after those Williams comments, but it's still in the red. \r\nYeah, and Bitcoin was one of the ma… [+1294 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Yahoo Finance Video',
#    'title': 'Nasdaq Composite falls as Nvidia gives up gains, bitcoin slides',
#    'description': 'Josh Lipton takes a closer look at three of the top stories on Wall Street. The Nasdaq Composite (^IXIC) is falling, reversing earlier gains, fueled by...',
#    'url': 'https://finance.yahoo.com/video/nasdaq-composite-falls-nvidia-gives-190900209.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/hgShZpdLZi4S1_ozW5dzKA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2025-11/ecac2ae0-c643-11f0-917f-30009031f4a9',
#    'publishedAt': '2025-11-20T19:09:00Z',
#    'content': "It's time for Yahoo Finance's Market Minute. Stocks giving back gains and then some as the risk off mood in markets resumes. The Nasdaq wiping out gains in a sharp reversal lower as Nvidia slides, in… [+816 chars]"},
# ...
#    'urlToImage': 'https://media.zenfs.com/en/thestreet_881/f9fa2849b9cfc41d63f7b2142c0ae1ca',
#    'publishedAt': '2025-12-08T21:34:22Z',
#    'content': 'Two long-dormant Bitcoin (BTC) wallets recently moved a total of 2,000 BTC worth approximately $180 million after more than 13 years.\r\nThe coins had remained dormant since 2011 and 2012, when Bitcoin… [+1999 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Khyathi Dalal',
#    'title': "Eric Trump Lauds Bitcoin: 'Send $500 Million On A Sunday Night, Virtually No Fees'",
#    'description': 'Eric Trump has doubled down on his pro-crypto stance, promoting Bitcoin (CRYPTO: BTC) as a fix for inefficiencies in traditional finance and calling it...',
#    'url': 'https://finance.yahoo.com/news/eric-trump-lauds-bitcoin-send-050408984.html',
#    'urlToImage': 'https://media.zenfs.com/en/benzinga_79/d98c3f868941a82afdc72b8c095c97b5',
#    'publishedAt': '2025-11-15T05:04:08Z',
#    'content': 'Benzinga and Yahoo Finance LLC may earn commission or revenue on some items through the links below.\r\nEric Trump has doubled down on his pro-crypto stance, promoting Bitcoin(CRYPTO: BTC) as a fix for… [+4677 chars]'},
#   {'source': {'id': None, 'name': 'Cryptonews'},
#    'author': 'Anas Hassan',
#    'title': 'Bitcoin Whales Dump 29,400 BTC at a Loss — But Analysts Say Stay Calm',
#    'description': 'Short-term Bitcoin holders just offloaded 29,400 BTC to exchanges at a loss, sparking fresh concerns about market pressure as the cryptocurrency hovers near ...',
#    'url': 'https://cryptonews.com/news/bitcoin-whales-dump-29400-btc-at-a-loss-but-analysts-say-stay-calm/',
#    'urlToImage': 'https://media.zenfs.com/en/cryptonews_us_711/0378e187d42dddeb189276a91e90b022',
#    'publishedAt': '2025-11-14T10:43:33Z',
#    'content': 'Short-term Bitcoin holders just offloaded 29,400 BTC to exchanges at a loss, sparking fresh concerns about market pressure as the cryptocurrency hovers near critical support levels.\r\nSource: X/@JA_Ma… [+4468 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Aniket Verma',
#    'title': 'Bitcoin Sinks Below $90,000: Popular Analyst Says This Is When BTC Will Reach Market Bottom',
#    'description': 'An influential cryptocurrency analyst predicted Monday when Bitcoin (CRYPTO: BTC) is likely to hit its bottom, even as the leading cryptocurrency crashed...',
#    'url': 'https://finance.yahoo.com/news/bitcoin-sinks-below-90-000-193807167.html',
#    'urlToImage': 'https://media.zenfs.com/en/benzinga_79/3ed4f1c980de7bdecf5c98a33f7b9900',
#    'publishedAt': '2025-11-18T19:38:07Z',
#    'content': 'Benzinga and Yahoo Finance LLC may earn commission or revenue on some items through the links below.\r\nAn influential cryptocurrency analyst predicted Monday when Bitcoin (CRYPTO: BTC) is likely to hi… [+4797 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Yahoo Finance Video',
#    'title': "Bitcoin's recent lows: How a new Fed chair could catalyze gains",
#    'description': 'Bitcoin (BTC-USD) fell as low as $84,000 on Monday, recording its worst day since March. Yahoo Finance Senior Reporter Ines Ferré and JonesTrading chief...',
#    'url': 'https://finance.yahoo.com/video/bitcoins-recent-lows-fed-chair-173000613.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/_KR1ybFYT6eLpnRKw.yAJA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzQ-/https://s.yimg.com/os/creatr-uploaded-images/2025-12/014cbfe0-cf91-11f0-bd1f-9b6385c2b869',
#    'publishedAt': '2025-12-02T17:30:00Z',
#    'content': "Mike, we're just talking about the outlook for Fed rate cuts. And, um, I have been fascinated to the extent to which Bitcoin has been trading off of those probabilities and that outlook. Um, and I kn… [+2376 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Simply Wall St',
#    'title': 'Riot Platforms (RIOT) Is Down 19.9% After October Drop in Bitcoin Output and Sales Activity - Has the Bull Case Changed?',
#    'description': 'Riot Platforms reported a decrease in October 2025 Bitcoin production to 437 coins and generated US$46.0 million in gross proceeds from selling 400 Bitcoins,...',
#    'url': 'https://finance.yahoo.com/news/riot-platforms-riot-down-19-010558110.html',
#    'urlToImage': 'https://media.zenfs.com/en/simply_wall_st__316/0fe4d5d105492213ce106a92b49639d4',
#    'publishedAt': '2025-11-18T01:05:58Z',
#    'content': '<ul><li>Riot Platforms reported a decrease in October 2025 Bitcoin production to 437 coins and generated US$46.0 million in gross proceeds from selling 400 Bitcoins, against the backdrop of recent in… [+3417 chars]'},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'Arjun Parashar',
#    'title': 'Bitcoin’s earliest billionaire empties entire portfolio after market crash',
#    'description': 'Bitcoin (BTC) whale Owen Gunden has sold his entire holdings. The eighth richest crypto holder in the world has unloaded roughly $1.3 billion worth of BTC...',
#    'url': 'https://www.thestreet.com/crypto/markets/bitcoins-earliest-billionaire-empties-entire-portfolio-after-market-crash',
#    'urlToImage': 'https://media.zenfs.com/en/thestreet_881/f2520285511800dfe0a69bc710d0c058',
#    'publishedAt': '2025-11-20T19:29:32Z',
#    'content': 'Bitcoin (BTC) whale Owen Gunden has sold his entire holdings.\r\nThe eighth richest crypto holder in the world has unloaded roughly $1.3 billion worth of BTC over the past month as retail sentiment plu… [+2081 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Aniket Verma',
#    'title': "Vladimir Putin Said Nothing Could Ban Bitcoin A Year Ago: Here's How Moscow Has Used Crypto Since Then To Overcome US Sanctions",
#    'description': 'Russian President Vladimir Putin asserted only a year ago that no power can ban Bitcoin (CRYPTO: BTC) regardless of what happens to the dollar. While many...',
#    'url': 'https://finance.yahoo.com/news/vladimir-putin-said-nothing-could-013107167.html',
#    'urlToImage': 'https://media.zenfs.com/en/benzinga_79/6fbffaea186f2549c48b8bb564970914',
#    'publishedAt': '2025-12-09T01:31:07Z',
#    'content': 'Benzinga and Yahoo Finance LLC may earn commission or revenue on some items through the links below.\r\nRussian President Vladimir Putin asserted only a year ago that no power can ban Bitcoin (CRYPTO: … [+5782 chars]'},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'Anand Sinha',
#    'title': 'Michael Saylor finally addresses short-sellers as mNav drops',
#    'description': 'Strategy (Nasdaq: MSTR) co-founder and executive chairman Michael Saylor has finally addressed the raging controversy over short-selling of MSTR shares by...',
#    'url': 'https://www.thestreet.com/crypto/trading/michael-saylor-finally-addresses-short-sellers-as-mnav-drops',
#    'urlToImage': 'https://media.zenfs.com/en/thestreet_881/d1aa5494f6ca9d52fa64ef014153b18a',
#    'publishedAt': '2025-11-13T19:44:04Z',
#    'content': 'Strategy (Nasdaq: MSTR) co-founder and executive chairman Michael Saylor has finally addressed the raging controversy over short-selling of MSTR shares by traders\xa0like Jim Chanos.\r\nIt was on\xa0Nov. 8 t… [+3095 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Rian Howlett',
#    'title': 'Stock market today: Dow, S&P 500, Nasdaq sink, bitcoin plummets in downbeat start to December',
#    'description': "Wall Street's strong late-November rebound looks set to hit a speed bump on the first trading day of December.",
#    'url': 'https://finance.yahoo.com/news/live/stock-market-today-dow-sp-500-nasdaq-sink-bitcoin-plummets-in-downbeat-start-to-december-011408608.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/lvmtNDwzV7lcqAQNJZd0kA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-10/6f40c5f0-a863-11f0-b3eb-c74a2e7e85d5',
#    'publishedAt': '2025-12-01T01:14:08Z',
#    'content': "Bitcoin (BTC-USD) tumbled more than 7% on Monday, along with crypto-related stocks, casting doubt on a year-end rally despite growing prospects of a Federal Reserve interest rate cut.\r\nThe world's la… [+1511 chars]"},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'Mehab Qureshi',
#    'title': '‘Rich Dad Poor Dad’ author sets new Bitcoin, Ethereum, gold price targets',
#    'description': 'Rich Dad Poor Dad author Robert Kiyosaki, the entrepreneur and investor best known for teaching millions about financial independence, has renewed his...',
#    'url': 'https://www.thestreet.com/crypto/personal-finance/rich-dad-poor-dad-author-sets-new-bitcoin-ethereum-gold-price-targets',
#    'urlToImage': 'https://media.zenfs.com/en/thestreet_881/29bbf3adfb664b2683204048c810b403',
#    'publishedAt': '2025-11-10T21:46:48Z',
#    'content': 'Rich Dad Poor Dad author Robert Kiyosaki, the entrepreneur and investor best known for teaching millions about financial independence, has renewed his outlook on Bitcoin (BTC), Ethereum (ETH) and pre… [+3416 chars]'},
#   {'source': {'id': None, 'name': 'Coingape'},
#    'author': 'Varinder Singh',
#    'title': 'Just-In: Elon Musk’s SpaceX Moves Another $100M in Bitcoin, What’s Happening?',
#    'description': 'Elon Musk’s space exploration company, SpaceX, moved massive 1,083 BTC on Friday, according to blockchain analytics firm Arkham Intelligence. This marks the ...',
#    'url': 'https://coingape.com/elon-musks-spacex-moves-another-100m-in-bitcoin/',
#    'urlToImage': 'https://media.zenfs.com/en/coingape_360/0111d29bcae96c9587143b663dc7b5ea',
#    'publishedAt': '2025-12-05T10:41:13Z',
#    'content': "Just-In: Elon Musk's SpaceX Moves Another $100M in Bitcoin, What's Happening? Source: CoinGape\r\n<ul><li>Elon Musks SpaceX transfers 1,083 BTC worth $100 million to new wallet.\r\n</li><li>The transfer … [+2600 chars]"},
#   {'source': {'id': None, 'name': 'Cryptonews'},
#    'author': 'Hassan Shittu',
#    'title': 'Analyst: Quantum Computers Will Break Bitcoin Politics, Unleashing Flood of Lost Coins',
#    'description': 'A prominent on-chain analyst has warned that the arrival of powerful quantum computers could trigger one of the most disruptive moments in Bitcoin’s history,...',
#    'url': 'https://cryptonews.com/news/quantum-computer-bitcoin-lost-coins/',
#    'urlToImage': 'https://media.zenfs.com/en/cryptonews_us_711/e6c4c7004c66d84a0d4b56a7a3212705',
#    'publishedAt': '2025-11-24T17:17:34Z',
#    'content': 'A prominent on-chain analyst has warned that the arrival of powerful quantum computers could trigger one of the most disruptive moments in Bitcoins history, not because of the technology itself, but … [+4344 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'David Hollerith',
#    'title': "Larry Fink softens crypto stance as BlackRock boasts biggest US bitcoin ETF: 'My thought process has evolved'",
#    'description': 'Larry Fink, once a proud crypto skeptic, has evolved his views as his firm, BlackRock, has become a leader in the industry.',
#    'url': 'https://finance.yahoo.com/news/larry-fink-softens-crypto-stance-as-blackrock-boasts-biggest-us-bitcoin-etf-my-thought-process-has-evolved-184909682.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/LCqYj_OUyWeEiQelje7S9A--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://s.yimg.com/os/creatr-uploaded-images/2025-12/3d8e6010-d074-11f0-b5df-33145c765fcd',
#    'publishedAt': '2025-12-03T18:49:09Z',
#    'content': 'Once a "proud skeptic of crypto, BlackRock (BLK) chairman and CEO Larry Fink continues to soften his stance on the digital currencies as his firm has become one of the biggest players in the increasi… [+3296 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Khac Phu Nguyen',
#    'title': "Bitcoin Darling Implodes: $1.5 Billion Vanishes as Strategy's ETF Frenzy Backfires",
#    'description': "Retail traders, leverage, and fading premiums collide in one of the year's most brutal crypto-linked equity meltdowns.",
#    'url': 'https://finance.yahoo.com/news/bitcoin-darling-implodes-1-5-114319619.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/Qpvwtsgs3wqWjA_qSjfm0A--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD03OTg-/https://media.zenfs.com/en/us.finance.gurufocus/fbaa0e585f3a84843ef3ff5b0c9aac53',
#    'publishedAt': '2025-12-02T11:43:19Z',
#    'content': "This article first appeared on GuruFocus.\r\nWhat looked like a clean way to ride Bitcoin's (BTC-USD) momentum has turned into a bruising lesson for investors who piled into Strategy Inc.'s grand exper… [+2251 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Parshwa Turakhiya',
#    'title': "Jim Cramer Notes 'Horrible' Bitcoin Start To December As BTC Falls By $4,000 In Minutes",
#    'description': 'Bitcoin (CRYPTO: BTC) is down almost 6% in the past 24 hours after a sudden wave of long-position liquidations erased nearly $4,000 from price in a matter of...',
#    'url': 'https://finance.yahoo.com/news/jim-cramer-notes-horrible-bitcoin-223337143.html',
#    'urlToImage': 'https://media.zenfs.com/en/benzinga_79/4ea2bfdebd9a4511b9439debc2f0905b',
#    'publishedAt': '2025-12-01T22:33:37Z',
#    'content': 'Benzinga and Yahoo Finance LLC may earn commission or revenue on some items through the links below.\r\nBitcoin(CRYPTO: BTC) is down almost 6% in the past 24 hours after a sudden wave of long-position … [+5434 chars]'},
#   {'source': {'id': None, 'name': 'Coinspeaker'},
#    'author': 'Parth Dubey',
#    'title': 'Crypto Trader James Wynn Gets Liquidated 12 Times in Just 12 Hours: What Happened?',
#    'description': 'The crypto market kicked off the week with a sharp rebound as Bitcoin BTC $105 299 24h volatility: 0.7% Market cap: $2.10 T Vol. 24h: $69.16 B surged nearly ...',
#    'url': 'https://www.coinspeaker.com/james-wynn-liquidated-12-times-12-hours/',
#    'urlToImage': 'https://media.zenfs.com/en/coinspeaker_us_106/b5b7719836f6cfb5856a0e5c524e6b87',
#    'publishedAt': '2025-11-10T11:34:35Z',
#    'content': 'The crypto market kicked off the week with a sharp rebound as Bitcoin surged nearly 4% on Nov. 10. Amid the upswing, crypto trader James Wynn, known for his aggressive trading style, was liquidated 1… [+1907 chars]'},
#   {'source': {'id': None, 'name': 'Dlnews.com'},
#    'author': 'Tim Alper',
#    'title': 'Chinese central bank doubles down on crypto crackdown as speculation resurfaces',
#    'description': 'Crypto transactions ‘remain illegal’ in China, say top officials. People’s Bank of China’s decision to reveal high-level crypto talks with ministries ‘is a...',
#    'url': 'https://www.dlnews.com/articles/regulation/chinese-central-bank-to-continue-crypto-crackdown/',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/_R_Pvw3AdriIH6FiNmHp2Q--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/dlnews_702/c837081707ef3513543d9eaf436a7191',
#    'publishedAt': '2025-11-30T10:58:36Z',
#    'content': 'Chinas central bank has quashed talk of relaxing its sweeping crackdown on crypto amid calls for Beijing to let Bitcoin miners return.\r\nThe Peoples Bank of China, also known as the PBoC, summoned rep… [+3217 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'nickthomas2@benzinga.com',
#    'title': "Crypto Treasury Companies Are Chasing Obscure Tokens—And That's Raising Red Flags About Market Volatility",
#    'description': 'As Bitcoin’s shine dulls and market saturation squeezes returns, a new breed of publicly traded crypto treasury companies is making a risky pivot that has...',
#    'url': 'https://finance.yahoo.com/news/crypto-treasury-companies-chasing-obscure-180025488.html',
#    'urlToImage': 'https://media.zenfs.com/en/benzinga_79/998d0df1b022a601411e8e79a3abbc32',
#    'publishedAt': '2025-11-28T18:00:25Z',
#    'content': 'Benzinga and Yahoo Finance LLC may earn commission or revenue on some items through the links below.\r\nAs Bitcoin’s shine dulls and market saturation squeezes returns, a new breed of publicly traded c… [+3697 chars]'}]}

# %%
len(news_resp['articles'])
# Out:
# 100

# %% [markdown]
# ## CryptoPanic:

# %%
# --- CONFIGURAZIONE ---
API_KEY = os.getenv("PANIC_KEY")
MONGO_URI = "mongodb://localhost:27017"
DB_NAME = "bitcoin_pr2"
COLL_NAME = "CryptoPanic_News" # Usiamo una collezione separata per ordine

# --- CONNESSIONE MONGO ---
client = MongoClient(MONGO_URI)
db = client[DB_NAME]
collection = db[COLL_NAME]

# --- CONFIGURAZIONE API ---
base_url = "https://cryptopanic.com/api/v1/posts/"
params = {
    "auth_token": API_KEY,
    "currencies": "BTC",    # Filtra solo Bitcoin
    "kind": "news",        # Solo notizie (esclude media/video)
    "public": "true"
}

print("Inizio scaricamento notizie da CryptoPanic...")

# Ciclo per scaricare più pagine
pagina_corrente = 1
max_pagine = 10  # Cambia questo numero se vuoi più dati

while base_url and pagina_corrente <= max_pagine:
    try:
        print(f"Scaricamento pagina {pagina_corrente}...")
        response = requests.get(base_url, params=params)
        data = response.json()
        
        # Controlla se ci sono risultati
        if "results" in data:
            posts = data["results"]
            
            # Inserimento in MongoDB
            if posts:
                # Aggiungiamo un campo per riconoscere la fonte facilmente
                for post in posts:
                    post['source_type'] = 'cryptopanic_api'
                
                collection.insert_many(posts)
                print(f"✅ Inseriti {len(posts)} articoli nel DB.")
            else:
                print("Nessun articolo trovato in questa pagina.")
        
        # Gestione Paginazione
        # L'API ci dà il link per la pagina successiva nel campo 'next'
        base_url = data.get("next")
        params = {} # I parametri sono già inclusi nell'url 'next', svuotiamo params
        
        pagina_corrente += 1
        time.sleep(1) # Pausa di cortesia per non essere bloccati
        
    except Exception as e:
        print(f"Errore: {e}")
        break

print("Finito!")
client.close()
# Out:
# Inizio scaricamento notizie da CryptoPanic...
# Scaricamento pagina 1...
# ✅ Inseriti 20 articoli nel DB.
# Finito!
